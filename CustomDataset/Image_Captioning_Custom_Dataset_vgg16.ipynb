# %% [markdown]
# <a href="https://colab.research.google.com/github/Vignesh-397/Image_Captioning/blob/main/CustomDataset/Image_Captioning_Custom_Dataset_vgg16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Basic libraries
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import warnings
warnings.filterwarnings('ignore')
from math import ceil
from collections import defaultdict
from tqdm.notebook import tqdm        # Progress bar library for Jupyter Notebook

# Deep learning framework for building and training models
import tensorflow as tf
## Pre-trained model for image feature extraction
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array

## Tokenizer class for captions tokenization
from tensorflow.keras.preprocessing.text import Tokenizer

## Function for padding sequences to a specific length
from tensorflow.keras.preprocessing.sequence import pad_sequences

## Class for defining Keras models
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, concatenate, Bidirectional, Dot, Activation, RepeatVector, Multiply, Lambda

# For checking score
from nltk.translate.bleu_score import corpus_bleu

# %%
# Setting the input and output directory
INPUT_DIR = '/content/drive/MyDrive/Major Project 2024/Dataset/Custom_Dataset'
OUTPUT_DIR = '/content/drive/MyDrive/Major Project 2024/Dataset/Custom_Dataset/v1_outputs'

# %%
# We are going to use pretraind vgg model
# Load the vgg16 model
model = VGG16()

# Restructuring the model to remove the last classification layer, this will give us access to the output features of the model
model = Model(inputs=model.inputs, outputs=model.layers[-2].output)

# Printing the model summary
print(model.summary())
# Out:
# Model: "functional_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc1 (Dense)                          │ (None, 4096)                │     102,764,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc2 (Dense)                          │ (None, 4096)                │      16,781,312 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 134,260,544 (512.16 MB)
#  Trainable params: 134,260,544 (512.16 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Initialize an empty dictionary to store image features
image_features = {}

# Define the directory path where images are located
img_dir = os.path.join(INPUT_DIR, 'Images')

# Loop through each image in the directory
for img_name in tqdm(os.listdir(img_dir)):
    # Load the image from file
    img_path = os.path.join(img_dir, img_name)
    image = load_img(img_path, target_size=(224, 224))
    # Convert image pixels to a numpy array
    image = img_to_array(image)
    # Reshape the data for the model
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    # Preprocess the image for ResNet50
    image = preprocess_input(image)
    # Extract features using the pre-trained ResNet50 model
    image_feature = model.predict(image, verbose=0)
    # Get the image ID by removing the file extension
    image_id = img_name.split('.')[0]
    # Store the extracted feature in the dictionary with the image ID as the key
    image_features[image_id] = image_feature
# Out:
#   0%|          | 0/330 [00:00<?, ?it/s]

# %%
# Store the image features in pickle
pickle.dump(image_features, open(os.path.join(OUTPUT_DIR, 'img_features_vgg16.pkl'), 'wb'))

# %%
# Load features from pickle file
pickle_file_path = os.path.join(OUTPUT_DIR, 'img_features_vgg16.pkl')
with open(pickle_file_path, 'rb') as file:
    loaded_features = pickle.load(file)

# %%
with open(os.path.join(INPUT_DIR, 'captions.txt'), 'r', encoding='ISO-8859-1') as file:
    next(file)  # skip the first line (if necessary)
    captions_doc = file.read()

# %%
# Create mapping of image to captions
image_to_captions_mapping = defaultdict(list)

# Process lines from captions_doc
for line in tqdm(captions_doc.split('\n')):
    # Split the line by comma(,)
    tokens = line.split(',')
    if len(tokens) < 2:
        continue
    image_id, *captions = tokens
    # Remove extension from image ID
    image_id = image_id.split('.')[0]
    # Convert captions list to string
    caption = " ".join(captions)
    # Store the caption using defaultdict
    image_to_captions_mapping[image_id].append(caption)

# Print the total number of captions
total_captions = sum(len(captions) for captions in image_to_captions_mapping.values())
print("Total number of captions:", total_captions)
# Out:
#   0%|          | 0/1648 [00:00<?, ?it/s]
# Total number of captions: 1645

# %%
# Function for processing the captions
def clean(mapping):
    for key, captions in mapping.items():
        for i in range(len(captions)):
            # Take one caption at a time
            caption = captions[i]
            # Preprocessing steps
            # Convert to lowercase
            caption = caption.lower()
            # Remove non-alphabetical characters
            caption = ''.join(char for char in caption if char.isalpha() or char.isspace())
            # Remove extra spaces
            caption = caption.replace('\s+', ' ')
            # Add unique start and end tokens to the caption
            caption = 'startseq ' + ' '.join([word for word in caption.split() if len(word) > 1]) + ' endseq'
            captions[i] = caption

# %%
# before preprocess of text
image_to_captions_mapping['002']
# Out:
# ['A black circular sports watch with a smooth round face  black straps and white minute and hour hands',
#  'A black sports watch with a circular dial and white hour and minute hands',
#  'A black circular sports watch with a smooth round face  black straps and white minute and hour hands',
#  'A circular black rigid watch with a sporty look and a black strap.',
#  'A sports watch with a round dial and a dotted black strap. It has white triangular minute and hour hands.']

# %%
# preprocess the text
clean(image_to_captions_mapping)

# %%
# after preprocess of text
image_to_captions_mapping['002']
# Out:
# ['startseq black circular sports watch with smooth round face black straps and white minute and hour hands endseq',
#  'startseq black sports watch with circular dial and white hour and minute hands endseq',
#  'startseq black circular sports watch with smooth round face black straps and white minute and hour hands endseq',
#  'startseq circular black rigid watch with sporty look and black strap endseq',
#  'startseq sports watch with round dial and dotted black strap it has white triangular minute and hour hands endseq']

# %%
# Creating a List of All Captions
all_captions = [caption for captions in image_to_captions_mapping.values() for caption in captions]

# %%
all_captions[:10]
# Out:
# ['startseq black circular sports watch with smooth round face black straps and white minute and hour hands endseq',
#  'startseq circular black watch with black strap and white hour and minute hands endseq',
#  'startseq circular sports watch with dotted black strap and white triangular minute and hour hands endseq',
#  'startseq black casio sports watch with black straps and gshock written on it endseq',
#  'startseq black circular sports watch with smooth round face black straps and white minute and hour hands endseq',
#  'startseq black sports watch with circular dial and white hour and minute hands endseq',
#  'startseq black circular sports watch with smooth round face black straps and white minute and hour hands endseq',
#  'startseq circular black rigid watch with sporty look and black strap endseq',
#  'startseq sports watch with round dial and dotted black strap it has white triangular minute and hour hands endseq',
#  'startseq black sports watch with circular dial and white hour and minute hands endseq']

# %%
# Tokenizing the Text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(all_captions)

# %%
# Save the tokenizer
with open('tokenizer.pkl', 'wb') as tokenizer_file:
    pickle.dump(tokenizer, tokenizer_file)

# Load the tokenizer
with open('tokenizer.pkl', 'rb') as tokenizer_file:
    tokenizer = pickle.load(tokenizer_file)

# %%
# Calculate maximum caption length
max_caption_length = max(len(tokenizer.texts_to_sequences([caption])[0]) for caption in all_captions)
vocab_size = len(tokenizer.word_index) + 1

# Print the results
print("Vocabulary Size:", vocab_size)
print("Maximum Caption Length:", max_caption_length)
# Out:
# Vocabulary Size: 915
# Maximum Caption Length: 42

# %%
# Creating a List of Image IDs
image_ids = list(image_to_captions_mapping.keys())
# Splitting into Training and Test Sets
split = int(len(image_ids) * 0.90)
train = image_ids[:split]
test = image_ids[split:]

# %%
def data_generator(data_keys, image_to_captions_mapping, features, tokenizer, max_caption_length, vocab_size, batch_size):
    # Lists to store batch data
    X1_batch, X2_batch, y_batch = [], [], []
    # Counter for the current batch size
    batch_count = 0

    while True:
        # Loop through each image in the current batch
        for image_id in data_keys:
            # Get the captions associated with the current image
            captions = image_to_captions_mapping[image_id]

            # Loop through each caption for the current image
            for caption in captions:
                # Convert the caption to a sequence of token IDs
                caption_seq = tokenizer.texts_to_sequences([caption])[0]

                # Loop through the tokens in the caption sequence
                for i in range(1, len(caption_seq)):
                    # Split the sequence into input and output pairs
                    in_seq, out_seq = caption_seq[:i], caption_seq[i]

                    # Pad the input sequence to the specified maximum caption length
                    # Changed padding to 'post' to right pad the sequences
                    in_seq = pad_sequences([in_seq], maxlen=max_caption_length, padding='post')[0]

                    # Convert the output sequence to one-hot encoded format
                    out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]

                    # Append data to batch lists
                    X1_batch.append(features[image_id][0])  # Image features
                    X2_batch.append(in_seq)  # Input sequence
                    y_batch.append(out_seq)  # Output sequence

                    # Increase the batch counter
                    batch_count += 1

                    # If the batch is complete, yield the batch and reset lists and counter
                    if batch_count == batch_size:
                        X1_batch, X2_batch, y_batch = np.array(X1_batch), np.array(X2_batch), np.array(y_batch)
                        # yield ([X1_batch, X2_batch], y_batch) # Old yield statement

                        # New yield statement using tf.data.Dataset.from_generator
                        # The function expects a single argument therefore combine X1 and X2
                        # and specify the type and shape for from_generator

                        # Changed the keys to match the input layer names
                        yield ({'input_layer_11':X1_batch, 'input_layer_12': X2_batch}, y_batch)
                        X1_batch, X2_batch, y_batch = [], [], []
                        batch_count = 0

# %%
# !pip install pycocoevalcap
# Out:
# Requirement already satisfied: pycocoevalcap in /usr/local/lib/python3.11/dist-packages (1.2)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from pycocoevalcap) (2.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pycocotools>=2.0.2->pycocoevalcap) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pycocotools>=2.0.2->pycocoevalcap) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.17.0)

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# Define Adam optimizer with a custom learning rate
optimizer = Adam(learning_rate=5e-5)  # Example: setting a smaller learning rate

# Encoder model
inputs1 = Input(shape=(4096,), name='input_layer_11')  # Assign name 'input_layer_11'
fe1 = Dropout(0.5)(inputs1)
fe2 = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(fe1)  # Added L2 regularization
fe2_projected = RepeatVector(max_caption_length)(fe2)
fe2_projected = Bidirectional(LSTM(256, return_sequences=True))(fe2_projected)

# Sequence feature layers
inputs2 = Input(shape=(max_caption_length,), name='input_layer_12')  # Assign name 'input_layer_12'
se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
se2 = Dropout(0.5)(se1)
se3 = Bidirectional(LSTM(256, return_sequences=True))(se2)

# Apply attention mechanism using Dot product
attention = Dot(axes=[2, 2])([fe2_projected, se3])  # Calculate attention scores

# Softmax attention scores
attention_scores = Activation('softmax')(attention)

# Apply attention scores to sequence embeddings
attention_context = Lambda(lambda x: tf.einsum('ijk,ijl->ikl', x[0], x[1]))([attention_scores, se3])

# Sum the attended sequence embeddings along the time axis using a Lambda layer
context_vector = Lambda(lambda x: tf.reduce_sum(x, axis=1))(attention_context)  # Wrap tf.reduce_sum in a Lambda layer

# Decoder model
decoder_input = concatenate([context_vector, fe2], axis=-1)
decoder1 = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(decoder_input)  # Added L2 regularization
outputs = Dense(vocab_size, activation='softmax')(decoder1)

# Create the model
model = Model(inputs=[inputs1, inputs2], outputs=outputs)
# Compile the model with the custom optimizer
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Visualize the model
plot_model(model, show_shapes=True)

# %%
# Learning Rate Scheduler Callback
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=5e-5)

# To store metrics for plotting
train_loss = []
val_loss = []
train_acc = []
val_acc = []

# Set the number of epochs, batch size
epochs = 200
batch_size = 32

# Calculate the steps_per_epoch based on the number of batches in one epoch
steps_per_epoch = ceil(len(train) / batch_size)
validation_steps = ceil(len(test) / batch_size)  # Calculate the steps for validation data

# Loop through the epochs for training
for epoch in range(epochs):
    print(f"Epoch {epoch+1}/{epochs}")

    # Set up data generators
    train_generator = data_generator(train, image_to_captions_mapping, loaded_features, tokenizer, max_caption_length, vocab_size, batch_size)
    test_generator = data_generator(test, image_to_captions_mapping, loaded_features, tokenizer, max_caption_length, vocab_size, batch_size)

    history = model.fit(
        train_generator,
        epochs=1,
        steps_per_epoch=steps_per_epoch,
        validation_data=test_generator,
        validation_steps=validation_steps,
        verbose=1,
        callbacks=[lr_scheduler]  # Add learning rate scheduler callback
    )

    # Append metrics for visualization
    train_loss.append(history.history['loss'][0])
    val_loss.append(history.history['val_loss'][0])
    train_acc.append(history.history['accuracy'][0])
    val_acc.append(history.history['val_accuracy'][0])
# Out:
# Epoch 1/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step - accuracy: 0.0000e+00 - loss: 15.4503 - val_accuracy: 0.0000e+00 - val_loss: 15.2020 - learning_rate: 5.0000e-05
# Epoch 2/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.0081 - loss: 14.9061 - val_accuracy: 0.0156 - val_loss: 14.9400 - learning_rate: 5.0000e-05
# Epoch 3/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.0304 - loss: 14.4538 - val_accuracy: 0.0938 - val_loss: 14.6663 - learning_rate: 5.0000e-05
# Epoch 4/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.0880 - loss: 13.9241 - val_accuracy: 0.0938 - val_loss: 14.3794 - learning_rate: 5.0000e-05
# Epoch 5/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.0962 - loss: 13.4019 - val_accuracy: 0.0938 - val_loss: 14.0793 - learning_rate: 5.0000e-05
# Epoch 6/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1177 - loss: 12.7218 - val_accuracy: 0.0938 - val_loss: 13.7927 - learning_rate: 5.0000e-05
# Epoch 7/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.0972 - loss: 12.1656 - val_accuracy: 0.0938 - val_loss: 13.5671 - learning_rate: 5.0000e-05
# Epoch 8/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.1596 - loss: 11.7100 - val_accuracy: 0.1562 - val_loss: 13.4220 - learning_rate: 5.0000e-05
# Epoch 9/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.1096 - loss: 11.3737 - val_accuracy: 0.1094 - val_loss: 13.3290 - learning_rate: 5.0000e-05
# Epoch 10/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1641 - loss: 11.1123 - val_accuracy: 0.1406 - val_loss: 13.2500 - learning_rate: 5.0000e-05
# Epoch 11/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1413 - loss: 10.8694 - val_accuracy: 0.1406 - val_loss: 13.1741 - learning_rate: 5.0000e-05
# Epoch 12/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1788 - loss: 10.6264 - val_accuracy: 0.1406 - val_loss: 13.0890 - learning_rate: 5.0000e-05
# Epoch 13/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1646 - loss: 10.4442 - val_accuracy: 0.1406 - val_loss: 12.9958 - learning_rate: 5.0000e-05
# Epoch 14/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1537 - loss: 10.2120 - val_accuracy: 0.1562 - val_loss: 12.8990 - learning_rate: 5.0000e-05
# Epoch 15/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1528 - loss: 10.0361 - val_accuracy: 0.1562 - val_loss: 12.8044 - learning_rate: 5.0000e-05
# Epoch 16/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1939 - loss: 9.8072 - val_accuracy: 0.1094 - val_loss: 12.7161 - learning_rate: 5.0000e-05
# Epoch 17/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1752 - loss: 9.7054 - val_accuracy: 0.1094 - val_loss: 12.6466 - learning_rate: 5.0000e-05
# Epoch 18/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1630 - loss: 9.4961 - val_accuracy: 0.1094 - val_loss: 12.5836 - learning_rate: 5.0000e-05
# Epoch 19/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.1869 - loss: 9.3419 - val_accuracy: 0.1094 - val_loss: 12.5252 - learning_rate: 5.0000e-05
# Epoch 20/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.1911 - loss: 9.2187 - val_accuracy: 0.1094 - val_loss: 12.4760 - learning_rate: 5.0000e-05
# Epoch 21/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1965 - loss: 9.0905 - val_accuracy: 0.1094 - val_loss: 12.4382 - learning_rate: 5.0000e-05
# Epoch 22/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.1783 - loss: 8.9496 - val_accuracy: 0.1094 - val_loss: 12.3902 - learning_rate: 5.0000e-05
# Epoch 23/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.1673 - loss: 8.8551 - val_accuracy: 0.1094 - val_loss: 12.3548 - learning_rate: 5.0000e-05
# Epoch 24/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.1980 - loss: 8.7259 - val_accuracy: 0.1562 - val_loss: 12.3173 - learning_rate: 5.0000e-05
# Epoch 25/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2203 - loss: 8.6532 - val_accuracy: 0.1094 - val_loss: 12.2919 - learning_rate: 5.0000e-05
# Epoch 26/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2073 - loss: 8.5736 - val_accuracy: 0.1562 - val_loss: 12.2524 - learning_rate: 5.0000e-05
# Epoch 27/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2291 - loss: 8.4489 - val_accuracy: 0.1094 - val_loss: 12.2219 - learning_rate: 5.0000e-05
# Epoch 28/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2030 - loss: 8.3984 - val_accuracy: 0.1562 - val_loss: 12.2033 - learning_rate: 5.0000e-05
# Epoch 29/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2264 - loss: 8.2671 - val_accuracy: 0.1562 - val_loss: 12.1830 - learning_rate: 5.0000e-05
# Epoch 30/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.2111 - loss: 8.2201 - val_accuracy: 0.1562 - val_loss: 12.1635 - learning_rate: 5.0000e-05
# Epoch 31/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2034 - loss: 8.1003 - val_accuracy: 0.1562 - val_loss: 12.1515 - learning_rate: 5.0000e-05
# Epoch 32/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.1929 - loss: 7.9961 - val_accuracy: 0.1562 - val_loss: 12.1432 - learning_rate: 5.0000e-05
# Epoch 33/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2288 - loss: 7.9188 - val_accuracy: 0.1562 - val_loss: 12.1332 - learning_rate: 5.0000e-05
# Epoch 34/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2191 - loss: 7.8371 - val_accuracy: 0.1562 - val_loss: 12.1383 - learning_rate: 5.0000e-05
# Epoch 35/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2169 - loss: 7.7822 - val_accuracy: 0.1562 - val_loss: 12.1361 - learning_rate: 5.0000e-05
# Epoch 36/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2139 - loss: 7.7032 - val_accuracy: 0.1562 - val_loss: 12.1461 - learning_rate: 5.0000e-05
# Epoch 37/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2556 - loss: 7.6086 - val_accuracy: 0.1562 - val_loss: 12.1370 - learning_rate: 5.0000e-05
# Epoch 38/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2189 - loss: 7.5405 - val_accuracy: 0.1562 - val_loss: 12.1540 - learning_rate: 5.0000e-05
# Epoch 39/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.2321 - loss: 7.4817 - val_accuracy: 0.1562 - val_loss: 12.1241 - learning_rate: 5.0000e-05
# Epoch 40/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2173 - loss: 7.4864 - val_accuracy: 0.1562 - val_loss: 12.1392 - learning_rate: 5.0000e-05
# Epoch 41/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2331 - loss: 7.3394 - val_accuracy: 0.1562 - val_loss: 12.1013 - learning_rate: 5.0000e-05
# Epoch 42/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2077 - loss: 7.3379 - val_accuracy: 0.1562 - val_loss: 12.1201 - learning_rate: 5.0000e-05
# Epoch 43/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2040 - loss: 7.2640 - val_accuracy: 0.1562 - val_loss: 12.0985 - learning_rate: 5.0000e-05
# Epoch 44/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2359 - loss: 7.1336 - val_accuracy: 0.1562 - val_loss: 12.1182 - learning_rate: 5.0000e-05
# Epoch 45/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2261 - loss: 7.1377 - val_accuracy: 0.1562 - val_loss: 12.0895 - learning_rate: 5.0000e-05
# Epoch 46/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2074 - loss: 7.0390 - val_accuracy: 0.1562 - val_loss: 12.1123 - learning_rate: 5.0000e-05
# Epoch 47/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2278 - loss: 7.0168 - val_accuracy: 0.1562 - val_loss: 12.1041 - learning_rate: 5.0000e-05
# Epoch 48/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2377 - loss: 7.0034 - val_accuracy: 0.1562 - val_loss: 12.1258 - learning_rate: 5.0000e-05
# Epoch 49/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2584 - loss: 6.8807 - val_accuracy: 0.1562 - val_loss: 12.1172 - learning_rate: 5.0000e-05
# Epoch 50/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2148 - loss: 6.8741 - val_accuracy: 0.1562 - val_loss: 12.1385 - learning_rate: 5.0000e-05
# Epoch 51/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.2514 - loss: 6.7778 - val_accuracy: 0.1562 - val_loss: 12.1063 - learning_rate: 5.0000e-05
# Epoch 52/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.2406 - loss: 6.7530 - val_accuracy: 0.1562 - val_loss: 12.1366 - learning_rate: 5.0000e-05
# Epoch 53/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.2247 - loss: 6.7184 - val_accuracy: 0.1562 - val_loss: 12.1087 - learning_rate: 5.0000e-05
# Epoch 54/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.2540 - loss: 6.6589 - val_accuracy: 0.1562 - val_loss: 12.1462 - learning_rate: 5.0000e-05
# Epoch 55/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2127 - loss: 6.5841 - val_accuracy: 0.1562 - val_loss: 12.1280 - learning_rate: 5.0000e-05
# Epoch 56/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2754 - loss: 6.5147 - val_accuracy: 0.1562 - val_loss: 12.1620 - learning_rate: 5.0000e-05
# Epoch 57/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2489 - loss: 6.5185 - val_accuracy: 0.1562 - val_loss: 12.1618 - learning_rate: 5.0000e-05
# Epoch 58/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2765 - loss: 6.4535 - val_accuracy: 0.1562 - val_loss: 12.2070 - learning_rate: 5.0000e-05
# Epoch 59/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2746 - loss: 6.3657 - val_accuracy: 0.1562 - val_loss: 12.1752 - learning_rate: 5.0000e-05
# Epoch 60/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3175 - loss: 6.3386 - val_accuracy: 0.1562 - val_loss: 12.2185 - learning_rate: 5.0000e-05
# Epoch 61/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2601 - loss: 6.3345 - val_accuracy: 0.1562 - val_loss: 12.1987 - learning_rate: 5.0000e-05
# Epoch 62/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2717 - loss: 6.2693 - val_accuracy: 0.1562 - val_loss: 12.2314 - learning_rate: 5.0000e-05
# Epoch 63/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2772 - loss: 6.2256 - val_accuracy: 0.1562 - val_loss: 12.2120 - learning_rate: 5.0000e-05
# Epoch 64/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3031 - loss: 6.1858 - val_accuracy: 0.1562 - val_loss: 12.2624 - learning_rate: 5.0000e-05
# Epoch 65/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2958 - loss: 6.1247 - val_accuracy: 0.1562 - val_loss: 12.2216 - learning_rate: 5.0000e-05
# Epoch 66/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3086 - loss: 6.1060 - val_accuracy: 0.1562 - val_loss: 12.2525 - learning_rate: 5.0000e-05
# Epoch 67/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3159 - loss: 6.0434 - val_accuracy: 0.1562 - val_loss: 12.2191 - learning_rate: 5.0000e-05
# Epoch 68/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3018 - loss: 6.0351 - val_accuracy: 0.1562 - val_loss: 12.2666 - learning_rate: 5.0000e-05
# Epoch 69/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3422 - loss: 5.9452 - val_accuracy: 0.1562 - val_loss: 12.2249 - learning_rate: 5.0000e-05
# Epoch 70/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3134 - loss: 5.9270 - val_accuracy: 0.1562 - val_loss: 12.3123 - learning_rate: 5.0000e-05
# Epoch 71/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3224 - loss: 5.8702 - val_accuracy: 0.1562 - val_loss: 12.1792 - learning_rate: 5.0000e-05
# Epoch 72/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3338 - loss: 5.8887 - val_accuracy: 0.1562 - val_loss: 12.2702 - learning_rate: 5.0000e-05
# Epoch 73/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3229 - loss: 5.8192 - val_accuracy: 0.1562 - val_loss: 12.2040 - learning_rate: 5.0000e-05
# Epoch 74/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2933 - loss: 5.8124 - val_accuracy: 0.1562 - val_loss: 12.2995 - learning_rate: 5.0000e-05
# Epoch 75/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3535 - loss: 5.7364 - val_accuracy: 0.1562 - val_loss: 12.2030 - learning_rate: 5.0000e-05
# Epoch 76/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3445 - loss: 5.7897 - val_accuracy: 0.1562 - val_loss: 12.3520 - learning_rate: 5.0000e-05
# Epoch 77/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.3275 - loss: 5.7945 - val_accuracy: 0.1562 - val_loss: 12.1780 - learning_rate: 5.0000e-05
# Epoch 78/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3524 - loss: 5.7052 - val_accuracy: 0.1562 - val_loss: 12.2896 - learning_rate: 5.0000e-05
# Epoch 79/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3226 - loss: 5.7044 - val_accuracy: 0.1562 - val_loss: 12.1865 - learning_rate: 5.0000e-05
# Epoch 80/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3462 - loss: 5.6190 - val_accuracy: 0.1562 - val_loss: 12.3029 - learning_rate: 5.0000e-05
# Epoch 81/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3497 - loss: 5.6178 - val_accuracy: 0.1562 - val_loss: 12.2052 - learning_rate: 5.0000e-05
# Epoch 82/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3666 - loss: 5.5315 - val_accuracy: 0.1562 - val_loss: 12.2588 - learning_rate: 5.0000e-05
# Epoch 83/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4002 - loss: 5.4881 - val_accuracy: 0.1562 - val_loss: 12.2850 - learning_rate: 5.0000e-05
# Epoch 84/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3394 - loss: 5.4966 - val_accuracy: 0.1562 - val_loss: 12.2235 - learning_rate: 5.0000e-05
# Epoch 85/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4285 - loss: 5.3886 - val_accuracy: 0.1562 - val_loss: 12.2658 - learning_rate: 5.0000e-05
# Epoch 86/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4014 - loss: 5.3595 - val_accuracy: 0.1562 - val_loss: 12.2435 - learning_rate: 5.0000e-05
# Epoch 87/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.3609 - loss: 5.3445 - val_accuracy: 0.1562 - val_loss: 12.3184 - learning_rate: 5.0000e-05
# Epoch 88/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.3919 - loss: 5.2847 - val_accuracy: 0.1562 - val_loss: 12.2757 - learning_rate: 5.0000e-05
# Epoch 89/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4162 - loss: 5.2868 - val_accuracy: 0.1562 - val_loss: 12.3000 - learning_rate: 5.0000e-05
# Epoch 90/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4309 - loss: 5.2476 - val_accuracy: 0.1562 - val_loss: 12.2923 - learning_rate: 5.0000e-05
# Epoch 91/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4165 - loss: 5.2049 - val_accuracy: 0.1562 - val_loss: 12.3016 - learning_rate: 5.0000e-05
# Epoch 92/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4155 - loss: 5.1740 - val_accuracy: 0.1562 - val_loss: 12.3110 - learning_rate: 5.0000e-05
# Epoch 93/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4151 - loss: 5.1824 - val_accuracy: 0.1562 - val_loss: 12.2901 - learning_rate: 5.0000e-05
# Epoch 94/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4415 - loss: 5.1418 - val_accuracy: 0.1562 - val_loss: 12.3527 - learning_rate: 5.0000e-05
# Epoch 95/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4010 - loss: 5.1402 - val_accuracy: 0.1562 - val_loss: 12.2811 - learning_rate: 5.0000e-05
# Epoch 96/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4816 - loss: 5.0770 - val_accuracy: 0.1562 - val_loss: 12.3551 - learning_rate: 5.0000e-05
# Epoch 97/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4131 - loss: 5.0551 - val_accuracy: 0.1562 - val_loss: 12.3653 - learning_rate: 5.0000e-05
# Epoch 98/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4495 - loss: 5.0049 - val_accuracy: 0.1562 - val_loss: 12.3417 - learning_rate: 5.0000e-05
# Epoch 99/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4445 - loss: 5.0187 - val_accuracy: 0.1562 - val_loss: 12.3537 - learning_rate: 5.0000e-05
# Epoch 100/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4632 - loss: 4.9553 - val_accuracy: 0.1562 - val_loss: 12.3570 - learning_rate: 5.0000e-05
# Epoch 101/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4878 - loss: 4.9606 - val_accuracy: 0.1562 - val_loss: 12.3601 - learning_rate: 5.0000e-05
# Epoch 102/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4791 - loss: 4.8766 - val_accuracy: 0.1562 - val_loss: 12.3714 - learning_rate: 5.0000e-05
# Epoch 103/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4776 - loss: 4.8492 - val_accuracy: 0.1562 - val_loss: 12.3742 - learning_rate: 5.0000e-05
# Epoch 104/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4577 - loss: 4.8371 - val_accuracy: 0.1562 - val_loss: 12.3809 - learning_rate: 5.0000e-05
# Epoch 105/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4939 - loss: 4.8243 - val_accuracy: 0.1562 - val_loss: 12.4022 - learning_rate: 5.0000e-05
# Epoch 106/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4972 - loss: 4.7861 - val_accuracy: 0.1562 - val_loss: 12.4473 - learning_rate: 5.0000e-05
# Epoch 107/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4738 - loss: 4.7726 - val_accuracy: 0.1562 - val_loss: 12.4323 - learning_rate: 5.0000e-05
# Epoch 108/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4485 - loss: 4.7639 - val_accuracy: 0.1562 - val_loss: 12.4761 - learning_rate: 5.0000e-05
# Epoch 109/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4676 - loss: 4.7570 - val_accuracy: 0.1562 - val_loss: 12.4478 - learning_rate: 5.0000e-05
# Epoch 110/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5044 - loss: 4.6952 - val_accuracy: 0.1562 - val_loss: 12.4684 - learning_rate: 5.0000e-05
# Epoch 111/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4870 - loss: 4.7051 - val_accuracy: 0.1562 - val_loss: 12.4216 - learning_rate: 5.0000e-05
# Epoch 112/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4670 - loss: 4.6596 - val_accuracy: 0.1562 - val_loss: 12.5108 - learning_rate: 5.0000e-05
# Epoch 113/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5032 - loss: 4.6455 - val_accuracy: 0.1562 - val_loss: 12.4689 - learning_rate: 5.0000e-05
# Epoch 114/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4533 - loss: 4.6208 - val_accuracy: 0.1562 - val_loss: 12.4649 - learning_rate: 5.0000e-05
# Epoch 115/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5056 - loss: 4.6008 - val_accuracy: 0.1562 - val_loss: 12.5057 - learning_rate: 5.0000e-05
# Epoch 116/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5009 - loss: 4.5769 - val_accuracy: 0.1562 - val_loss: 12.4954 - learning_rate: 5.0000e-05
# Epoch 117/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4710 - loss: 4.6043 - val_accuracy: 0.1562 - val_loss: 12.5483 - learning_rate: 5.0000e-05
# Epoch 118/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4848 - loss: 4.5637 - val_accuracy: 0.1562 - val_loss: 12.4337 - learning_rate: 5.0000e-05
# Epoch 119/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4833 - loss: 4.5304 - val_accuracy: 0.1562 - val_loss: 12.5266 - learning_rate: 5.0000e-05
# Epoch 120/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4755 - loss: 4.4796 - val_accuracy: 0.1562 - val_loss: 12.4748 - learning_rate: 5.0000e-05
# Epoch 121/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5425 - loss: 4.4410 - val_accuracy: 0.1562 - val_loss: 12.5119 - learning_rate: 5.0000e-05
# Epoch 122/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5161 - loss: 4.4062 - val_accuracy: 0.1562 - val_loss: 12.5094 - learning_rate: 5.0000e-05
# Epoch 123/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5576 - loss: 4.4019 - val_accuracy: 0.1562 - val_loss: 12.4948 - learning_rate: 5.0000e-05
# Epoch 124/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5736 - loss: 4.3376 - val_accuracy: 0.1562 - val_loss: 12.5489 - learning_rate: 5.0000e-05
# Epoch 125/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5184 - loss: 4.4026 - val_accuracy: 0.1562 - val_loss: 12.5016 - learning_rate: 5.0000e-05
# Epoch 126/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5288 - loss: 4.3236 - val_accuracy: 0.1562 - val_loss: 12.5977 - learning_rate: 5.0000e-05
# Epoch 127/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5167 - loss: 4.3295 - val_accuracy: 0.1562 - val_loss: 12.4892 - learning_rate: 5.0000e-05
# Epoch 128/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5392 - loss: 4.2963 - val_accuracy: 0.1562 - val_loss: 12.5908 - learning_rate: 5.0000e-05
# Epoch 129/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4860 - loss: 4.3513 - val_accuracy: 0.1562 - val_loss: 12.5446 - learning_rate: 5.0000e-05
# Epoch 130/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5503 - loss: 4.3156 - val_accuracy: 0.1562 - val_loss: 12.5591 - learning_rate: 5.0000e-05
# Epoch 131/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5474 - loss: 4.2495 - val_accuracy: 0.1562 - val_loss: 12.5425 - learning_rate: 5.0000e-05
# Epoch 132/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5200 - loss: 4.2098 - val_accuracy: 0.1562 - val_loss: 12.5899 - learning_rate: 5.0000e-05
# Epoch 133/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5783 - loss: 4.1835 - val_accuracy: 0.1562 - val_loss: 12.5723 - learning_rate: 5.0000e-05
# Epoch 134/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5801 - loss: 4.1454 - val_accuracy: 0.1562 - val_loss: 12.5797 - learning_rate: 5.0000e-05
# Epoch 135/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5745 - loss: 4.1262 - val_accuracy: 0.1562 - val_loss: 12.6082 - learning_rate: 5.0000e-05
# Epoch 136/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5431 - loss: 4.1407 - val_accuracy: 0.1562 - val_loss: 12.6068 - learning_rate: 5.0000e-05
# Epoch 137/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5711 - loss: 4.1152 - val_accuracy: 0.1562 - val_loss: 12.6305 - learning_rate: 5.0000e-05
# Epoch 138/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6146 - loss: 4.0370 - val_accuracy: 0.1562 - val_loss: 12.6157 - learning_rate: 5.0000e-05
# Epoch 139/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6100 - loss: 4.0420 - val_accuracy: 0.1562 - val_loss: 12.6362 - learning_rate: 5.0000e-05
# Epoch 140/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5726 - loss: 4.0138 - val_accuracy: 0.1562 - val_loss: 12.6536 - learning_rate: 5.0000e-05
# Epoch 141/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5668 - loss: 4.0190 - val_accuracy: 0.1562 - val_loss: 12.6638 - learning_rate: 5.0000e-05
# Epoch 142/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5677 - loss: 4.0164 - val_accuracy: 0.1562 - val_loss: 12.6718 - learning_rate: 5.0000e-05
# Epoch 143/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5875 - loss: 3.9737 - val_accuracy: 0.1562 - val_loss: 12.6234 - learning_rate: 5.0000e-05
# Epoch 144/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6129 - loss: 3.9580 - val_accuracy: 0.1562 - val_loss: 12.7443 - learning_rate: 5.0000e-05
# Epoch 145/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6047 - loss: 3.9324 - val_accuracy: 0.1562 - val_loss: 12.6786 - learning_rate: 5.0000e-05
# Epoch 146/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5721 - loss: 3.9568 - val_accuracy: 0.1562 - val_loss: 12.7032 - learning_rate: 5.0000e-05
# Epoch 147/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5833 - loss: 3.8985 - val_accuracy: 0.1562 - val_loss: 12.7080 - learning_rate: 5.0000e-05
# Epoch 148/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6153 - loss: 3.9130 - val_accuracy: 0.1562 - val_loss: 12.7381 - learning_rate: 5.0000e-05
# Epoch 149/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5443 - loss: 3.8901 - val_accuracy: 0.1562 - val_loss: 12.7316 - learning_rate: 5.0000e-05
# Epoch 150/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6063 - loss: 3.8694 - val_accuracy: 0.1562 - val_loss: 12.7736 - learning_rate: 5.0000e-05
# Epoch 151/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5536 - loss: 3.8563 - val_accuracy: 0.1562 - val_loss: 12.7888 - learning_rate: 5.0000e-05
# Epoch 152/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6231 - loss: 3.7948 - val_accuracy: 0.1562 - val_loss: 12.7936 - learning_rate: 5.0000e-05
# Epoch 153/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6231 - loss: 3.7807 - val_accuracy: 0.1562 - val_loss: 12.7874 - learning_rate: 5.0000e-05
# Epoch 154/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5992 - loss: 3.7904 - val_accuracy: 0.1562 - val_loss: 12.8362 - learning_rate: 5.0000e-05
# Epoch 155/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5796 - loss: 3.7703 - val_accuracy: 0.1406 - val_loss: 12.7705 - learning_rate: 5.0000e-05
# Epoch 156/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6169 - loss: 3.7739 - val_accuracy: 0.1562 - val_loss: 12.8789 - learning_rate: 5.0000e-05
# Epoch 157/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6117 - loss: 3.7738 - val_accuracy: 0.1562 - val_loss: 12.8705 - learning_rate: 5.0000e-05
# Epoch 158/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6460 - loss: 3.7144 - val_accuracy: 0.1562 - val_loss: 12.8867 - learning_rate: 5.0000e-05
# Epoch 159/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6296 - loss: 3.7027 - val_accuracy: 0.1562 - val_loss: 12.8573 - learning_rate: 5.0000e-05
# Epoch 160/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6091 - loss: 3.6990 - val_accuracy: 0.1562 - val_loss: 12.9452 - learning_rate: 5.0000e-05
# Epoch 161/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6041 - loss: 3.6774 - val_accuracy: 0.1562 - val_loss: 12.8800 - learning_rate: 5.0000e-05
# Epoch 162/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5648 - loss: 3.7207 - val_accuracy: 0.1406 - val_loss: 12.8668 - learning_rate: 5.0000e-05
# Epoch 163/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6386 - loss: 3.6543 - val_accuracy: 0.1562 - val_loss: 12.8617 - learning_rate: 5.0000e-05
# Epoch 164/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6385 - loss: 3.6491 - val_accuracy: 0.1562 - val_loss: 12.8574 - learning_rate: 5.0000e-05
# Epoch 165/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6032 - loss: 3.6049 - val_accuracy: 0.1562 - val_loss: 12.8828 - learning_rate: 5.0000e-05
# Epoch 166/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6056 - loss: 3.6014 - val_accuracy: 0.1406 - val_loss: 12.8674 - learning_rate: 5.0000e-05
# Epoch 167/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6543 - loss: 3.5450 - val_accuracy: 0.1562 - val_loss: 12.9246 - learning_rate: 5.0000e-05
# Epoch 168/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5970 - loss: 3.5973 - val_accuracy: 0.1406 - val_loss: 12.9148 - learning_rate: 5.0000e-05
# Epoch 169/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6316 - loss: 3.5334 - val_accuracy: 0.1562 - val_loss: 12.9596 - learning_rate: 5.0000e-05
# Epoch 170/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6482 - loss: 3.5401 - val_accuracy: 0.1406 - val_loss: 12.9209 - learning_rate: 5.0000e-05
# Epoch 171/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6607 - loss: 3.5065 - val_accuracy: 0.1406 - val_loss: 12.9209 - learning_rate: 5.0000e-05
# Epoch 172/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5869 - loss: 3.5357 - val_accuracy: 0.1406 - val_loss: 12.9515 - learning_rate: 5.0000e-05
# Epoch 173/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5767 - loss: 3.5685 - val_accuracy: 0.1562 - val_loss: 13.0121 - learning_rate: 5.0000e-05
# Epoch 174/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6004 - loss: 3.5699 - val_accuracy: 0.1406 - val_loss: 12.9234 - learning_rate: 5.0000e-05
# Epoch 175/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6433 - loss: 3.4842 - val_accuracy: 0.1562 - val_loss: 12.9754 - learning_rate: 5.0000e-05
# Epoch 176/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6232 - loss: 3.5430 - val_accuracy: 0.1406 - val_loss: 12.9221 - learning_rate: 5.0000e-05
# Epoch 177/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6198 - loss: 3.5008 - val_accuracy: 0.1562 - val_loss: 12.9834 - learning_rate: 5.0000e-05
# Epoch 178/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6558 - loss: 3.4294 - val_accuracy: 0.1406 - val_loss: 12.9437 - learning_rate: 5.0000e-05
# Epoch 179/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6438 - loss: 3.4217 - val_accuracy: 0.1562 - val_loss: 13.0357 - learning_rate: 5.0000e-05
# Epoch 180/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6696 - loss: 3.3856 - val_accuracy: 0.1562 - val_loss: 12.9805 - learning_rate: 5.0000e-05
# Epoch 181/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6286 - loss: 3.3951 - val_accuracy: 0.1406 - val_loss: 12.9004 - learning_rate: 5.0000e-05
# Epoch 182/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6471 - loss: 3.3832 - val_accuracy: 0.1562 - val_loss: 13.0478 - learning_rate: 5.0000e-05
# Epoch 183/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6746 - loss: 3.3777 - val_accuracy: 0.1562 - val_loss: 12.9421 - learning_rate: 5.0000e-05
# Epoch 184/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6433 - loss: 3.3373 - val_accuracy: 0.1406 - val_loss: 12.9688 - learning_rate: 5.0000e-05
# Epoch 185/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6845 - loss: 3.2980 - val_accuracy: 0.1406 - val_loss: 13.0035 - learning_rate: 5.0000e-05
# Epoch 186/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6940 - loss: 3.2821 - val_accuracy: 0.1562 - val_loss: 13.0012 - learning_rate: 5.0000e-05
# Epoch 187/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6970 - loss: 3.2799 - val_accuracy: 0.1562 - val_loss: 12.9791 - learning_rate: 5.0000e-05
# Epoch 188/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7144 - loss: 3.2473 - val_accuracy: 0.1562 - val_loss: 13.0206 - learning_rate: 5.0000e-05
# Epoch 189/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7302 - loss: 3.2606 - val_accuracy: 0.1406 - val_loss: 13.0294 - learning_rate: 5.0000e-05
# Epoch 190/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7037 - loss: 3.2415 - val_accuracy: 0.1406 - val_loss: 13.0433 - learning_rate: 5.0000e-05
# Epoch 191/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6995 - loss: 3.2510 - val_accuracy: 0.1562 - val_loss: 13.0771 - learning_rate: 5.0000e-05
# Epoch 192/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7119 - loss: 3.2066 - val_accuracy: 0.1406 - val_loss: 13.0244 - learning_rate: 5.0000e-05
# Epoch 193/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7402 - loss: 3.1774 - val_accuracy: 0.1406 - val_loss: 13.0764 - learning_rate: 5.0000e-05
# Epoch 194/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6594 - loss: 3.2043 - val_accuracy: 0.1406 - val_loss: 13.1158 - learning_rate: 5.0000e-05
# Epoch 195/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7092 - loss: 3.1967 - val_accuracy: 0.1406 - val_loss: 13.0493 - learning_rate: 5.0000e-05
# Epoch 196/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7071 - loss: 3.1479 - val_accuracy: 0.1719 - val_loss: 13.1043 - learning_rate: 5.0000e-05
# Epoch 197/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6948 - loss: 3.1612 - val_accuracy: 0.1406 - val_loss: 13.0926 - learning_rate: 5.0000e-05
# Epoch 198/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6853 - loss: 3.1504 - val_accuracy: 0.1719 - val_loss: 13.0944 - learning_rate: 5.0000e-05
# Epoch 199/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7206 - loss: 3.1264 - val_accuracy: 0.1562 - val_loss: 13.1022 - learning_rate: 5.0000e-05
# Epoch 200/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7473 - loss: 3.0946 - val_accuracy: 0.1719 - val_loss: 13.1416 - learning_rate: 5.0000e-05

# %%
import matplotlib.pyplot as plt

# Plot the training and validation loss
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(range(1, epochs + 1), train_loss, label='Train Loss')
plt.plot(range(1, epochs + 1), val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Plot the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs + 1), train_acc, label='Train Accuracy')
plt.plot(range(1, epochs + 1), val_acc, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Save the model
model.save(OUTPUT_DIR+'/image_captioning_model_vgg16.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
def get_word_from_index(index, tokenizer):
    return next((word for word, idx in tokenizer.word_index.items() if idx == index), None)

# %%
def predict_caption(model, image_features, tokenizer, max_caption_length):
    # Initialize the caption sequence
    caption = 'startseq'

    # Generate the caption
    for _ in range(max_caption_length):
        # Convert the current caption to a sequence of token indices
        sequence = tokenizer.texts_to_sequences([caption])[0]
        # Pad the sequence to match the maximum caption length, ensuring right padding
        sequence = pad_sequences([sequence], maxlen=max_caption_length, padding='post')  # Changed padding to 'post'
        # Predict the next word's probability distribution
        yhat = model.predict([image_features, sequence], verbose=0)
        # Get the index with the highest probability
        predicted_index = np.argmax(yhat)
        # Convert the index to a word
        predicted_word = get_word_from_index(predicted_index, tokenizer)

        # Append the predicted word to the caption
        caption += " " + predicted_word

        # Stop if the word is None or if the end sequence tag is encountered
        if predicted_word is None or predicted_word == 'endseq':
            break

    return caption

# %%
# !pip install rouge-score
# !pip install nltk
import nltk
nltk.download('wordnet')
# Out:
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.11/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (4.67.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Required Imports
from tqdm import tqdm
from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.meteor_score import meteor_score
from rouge_score import rouge_scorer
from pycocoevalcap.cider.cider import Cider
from pycocoevalcap.spice.spice import Spice
from collections import defaultdict
import pandas as pd

# Initialize lists to store actual and predicted captions
actual_captions_list = []
predicted_captions_list = []

# Metrics storage
meteor_scores = []
rouge_scores = defaultdict(list)
cider_scorer = Cider()
spice_scorer = Spice()

# Variables to store SPICE and CIDEr scores
cider_scores = []
spice_scores = []

# Loop through the test data
for key in tqdm(test):
    # Get actual captions for the current image
    actual_captions = image_to_captions_mapping[key]
    # Predict the caption for the image using the model
    predicted_caption = predict_caption(model, loaded_features[key], tokenizer, max_caption_length)

    # Split actual captions into words
    actual_captions_words = [caption.split() for caption in actual_captions]  # Tokenize actual captions
    # Split predicted caption into words
    predicted_caption_words = predicted_caption.split()

    # Append to the lists
    actual_captions_list.append(actual_captions_words)
    predicted_captions_list.append(predicted_caption_words)

    # Calculate METEOR
    meteor_scores.append(
        max([meteor_score([caption.split()], predicted_caption.split()) for caption in actual_captions])
    )
    # Calculate ROUGE
    scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL"], use_stemmer=True)
    for caption in actual_captions:
        scores = scorer.score(caption, predicted_caption)
        for metric, score in scores.items():
            rouge_scores[metric].append(score.fmeasure)

    # Prepare CIDEr and SPICE evaluation inputs
    # Create dictionaries for scorers: {image_id: [caption]}
    actual_dict = {0: actual_captions}
    predicted_dict = {0: [predicted_caption]}

    # Calculate CIDEr and SPICE scores
    cider_score, _ = cider_scorer.compute_score(actual_dict, predicted_dict)
    spice_score, _ = spice_scorer.compute_score(actual_dict, predicted_dict)
    cider_scores.append(cider_score)
    spice_scores.append(spice_score)

# Calculate BLEU scores
bleu1 = corpus_bleu(actual_captions_list, predicted_captions_list, weights=(1.0, 0, 0, 0))
bleu2 = corpus_bleu(actual_captions_list, predicted_captions_list, weights=(0.5, 0.5, 0, 0))
bleu3 = corpus_bleu(actual_captions_list, predicted_captions_list, weights=(0.33, 0.33, 0.33, 0))
bleu4 = corpus_bleu(actual_captions_list, predicted_captions_list, weights=(0.25, 0.25, 0.25, 0.25))

# Calculate average ROUGE scores
avg_rouge1 = sum(rouge_scores["rouge1"]) / len(rouge_scores["rouge1"])
avg_rouge2 = sum(rouge_scores["rouge2"]) / len(rouge_scores["rouge2"])
avg_rougeL = sum(rouge_scores["rougeL"]) / len(rouge_scores["rougeL"])

# Calculate average CIDEr and SPICE scores
avg_cider = sum(cider_scores) / len(cider_scores)
avg_spice = sum(spice_scores) / len(spice_scores)

# Create table
metrics_table = pd.DataFrame({
    "Metric": ["BLEU-1", "BLEU-2", "BLEU-3", "BLEU-4", "METEOR", "ROUGE-1", "ROUGE-2", "ROUGE-L", "CIDEr", "SPICE"],
    "Score": [
        bleu1,
        bleu2,
        bleu3,
        bleu4,
        sum(meteor_scores) / len(meteor_scores),
        avg_rouge1,
        avg_rouge2,
        avg_rougeL,
        avg_cider,
        avg_spice,
    ]
})

# Print table
print("\n")
print(metrics_table.to_markdown(index=False))
# Out:
# 100%|██████████| 33/33 [04:49<00:00,  8.79s/it]
# | Metric   |        Score |
# |:---------|-------------:|
# | BLEU-1   | 0.541872     |
# | BLEU-2   | 0.169373     |
# | BLEU-3   | 9.23978e-103 |
# | BLEU-4   | 6.13896e-155 |
# | METEOR   | 0.317579     |
# | ROUGE-1  | 0.407475     |
# | ROUGE-2  | 0.0343236    |
# | ROUGE-L  | 0.4018       |
# | CIDEr    | 0            |
# | SPICE    | 0.102951     |

# %%
# Function for generating caption
def generate_caption(image_name):
    # load the image
    image_id = image_name.split('.')[0]
    img_path = os.path.join(INPUT_DIR, "Images", image_name)
    image = Image.open(img_path)
    captions = image_to_captions_mapping[image_id]
    print('---------------------Actual---------------------')
    for caption in captions:
        print(caption)
    # predict the caption
    y_pred = predict_caption(model, loaded_features[image_id], tokenizer, max_caption_length)
    print('--------------------Predicted--------------------')
    print(y_pred)
    plt.imshow(image)

# %%
generate_caption("003.jpg")
# Out:
# ---------------------Actual---------------------
# startseq black sports watch with circular dial and white hour and minute hands endseq
# startseq black circular sports watch with smooth round face black straps and white minute and hour hands endseq
# startseq black circular sports watch with smooth round face black straps and white minute and hour hands endseq
# startseq black round sports watch with silver back case endseq
# startseq rounddial sports watch with silver back case endseq
# --------------------Predicted--------------------
# startseq black sports watch with silver back case endseq

# %% [markdown]
# ##**Caption Generation For Unseen Image**

# %%
# We are going to use pretraind vgg model
# Load the vgg16 model
model_1 = VGG16()

# Restructuring the model to remove the last classification layer, this will give us access to the output features of the model
model_1 = Model(inputs=model_1.inputs, outputs=model_1.layers[-2].output)


def generate_caption_for_new_image(image_path):
    # Load and preprocess the new image
    image = load_img(image_path, target_size=(224, 224))
    image = img_to_array(image)
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    image = preprocess_input(image)

    # Extract features using the pre-trained ResNet50 model
    image_features = model_1.predict(image, verbose=0)  # Replace 'model' with 'feature_extraction_model'

    # Generate caption
    caption = 'startseq'
    for _ in range(max_caption_length):
        # Convert the current caption to a sequence
        sequence = tokenizer.texts_to_sequences([caption])[0]
        sequence = pad_sequences([sequence], maxlen=max_caption_length, padding='post')

        # Predict the next word
        yhat = model.predict([image_features, sequence], verbose=0)  # Use the caption generation model
        predicted_index = np.argmax(yhat)
        predicted_word = get_word_from_index(predicted_index, tokenizer)

        if predicted_word is None or predicted_word == 'endseq':
            break
        caption += ' ' + predicted_word

    # Remove startseq and endseq for readability
    caption = caption.replace('startseq', '').replace('endseq', '').strip()

    # Display the image and its caption
    img = Image.open(image_path)
    plt.imshow(img)
    plt.axis('off')
    plt.title("Predicted Caption:\n" + caption)
    plt.show()

# Example usage:
new_image_path = '/content/download.png'  # Replace with your image path
generate_caption_for_new_image(new_image_path)
