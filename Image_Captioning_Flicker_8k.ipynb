# %% [markdown]
# <a href="https://colab.research.google.com/github/Vignesh-397/Image_Captioning/blob/main/Image_Captioning_Flicker_8k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Basic libraries
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import warnings
warnings.filterwarnings('ignore')
from math import ceil
from collections import defaultdict
from tqdm.notebook import tqdm        # Progress bar library for Jupyter Notebook

# Deep learning framework for building and training models
import tensorflow as tf
## Pre-trained model for image feature extraction
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array

## Tokenizer class for captions tokenization
from tensorflow.keras.preprocessing.text import Tokenizer

## Function for padding sequences to a specific length
from tensorflow.keras.preprocessing.sequence import pad_sequences

## Class for defining Keras models
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, concatenate, Bidirectional, Dot, Activation, RepeatVector, Multiply, Lambda

# For checking score
from nltk.translate.bleu_score import corpus_bleu

# %%
# Setting the input and output directory
INPUT_DIR = '/content/drive/MyDrive/Major Project 2024/Dataset/flicker_8k'
OUTPUT_DIR = '/content/drive/MyDrive/Major Project 2024/Dataset/outputs'

# %%
# We are going to use pretraind vgg model
# Load the vgg16 model
model = VGG16()

# Restructuring the model to remove the last classification layer, this will give us access to the output features of the model
model = Model(inputs=model.inputs, outputs=model.layers[-2].output)

# Printing the model summary
print(model.summary())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 25s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc1 (Dense)                          │ (None, 4096)                │     102,764,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc2 (Dense)                          │ (None, 4096)                │      16,781,312 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 134,260,544 (512.16 MB)
#  Trainable params: 134,260,544 (512.16 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Initialize an empty dictionary to store image features
image_features = {}

# Define the directory path where images are located
img_dir = os.path.join(INPUT_DIR, 'Images')

# Loop through each image in the directory
for img_name in tqdm(os.listdir(img_dir)):
    # Load the image from file
    img_path = os.path.join(img_dir, img_name)
    image = load_img(img_path, target_size=(224, 224))
    # Convert image pixels to a numpy array
    image = img_to_array(image)
    # Reshape the data for the model
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    # Preprocess the image for ResNet50
    image = preprocess_input(image)
    # Extract features using the pre-trained ResNet50 model
    image_feature = model.predict(image, verbose=0)
    # Get the image ID by removing the file extension
    image_id = img_name.split('.')[0]
    # Store the extracted feature in the dictionary with the image ID as the key
    image_features[image_id] = image_feature
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3a26f3961826> in <cell line: 8>()
#       6
#       7 # Loop through each image in the directory
# ----> 8 for img_name in tqdm(os.listdir(img_dir)):
#       9     # Load the image from file
#      10     img_path = os.path.join(img_dir, img_name)
#
# KeyboardInterrupt:

# %%
# Store the image features in pickle
pickle.dump(image_features, open(os.path.join(OUTPUT_DIR, 'img_features.pkl'), 'wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-78864483550e> in <cell line: 2>()
#       1 # Store the image features in pickle
# ----> 2 pickle.dump(image_features, open(os.path.join(OUTPUT_DIR, 'img_features.pkl'), 'wb'))
#
# NameError: name 'image_features' is not defined

# %%
# Load features from pickle file
pickle_file_path = os.path.join(OUTPUT_DIR, 'img_features.pkl')
with open(pickle_file_path, 'rb') as file:
    loaded_features = pickle.load(file)

# %%
with open(os.path.join(INPUT_DIR, 'captions.txt'), 'r') as file:
    next(file)
    captions_doc = file.read()

# %%
# Create mapping of image to captions
image_to_captions_mapping = defaultdict(list)

# Process lines from captions_doc
for line in tqdm(captions_doc.split('\n')):
    # Split the line by comma(,)
    tokens = line.split(',')
    if len(tokens) < 2:
        continue
    image_id, *captions = tokens
    # Remove extension from image ID
    image_id = image_id.split('.')[0]
    # Convert captions list to string
    caption = " ".join(captions)
    # Store the caption using defaultdict
    image_to_captions_mapping[image_id].append(caption)

# Print the total number of captions
total_captions = sum(len(captions) for captions in image_to_captions_mapping.values())
print("Total number of captions:", total_captions)
# Out:
#   0%|          | 0/40456 [00:00<?, ?it/s]
# Total number of captions: 40455

# %%
# Function for processing the captions
def clean(mapping):
    for key, captions in mapping.items():
        for i in range(len(captions)):
            # Take one caption at a time
            caption = captions[i]
            # Preprocessing steps
            # Convert to lowercase
            caption = caption.lower()
            # Remove non-alphabetical characters
            caption = ''.join(char for char in caption if char.isalpha() or char.isspace())
            # Remove extra spaces
            caption = caption.replace('\s+', ' ')
            # Add unique start and end tokens to the caption
            caption = 'startseq ' + ' '.join([word for word in caption.split() if len(word) > 1]) + ' endseq'
            captions[i] = caption

# %%
# before preprocess of text
image_to_captions_mapping['1026685415_0431cbf574']
# Out:
# ['A black dog carries a green toy in his mouth as he walks through the grass .',
#  'A black dog carrying something through the grass .',
#  'A black dog has a blue toy in its mouth .',
#  'A dog in grass with a blue item in his mouth .',
#  'A wet black dog is carrying a green toy through the grass .']

# %%
# preprocess the text
clean(image_to_captions_mapping)

# %%
# after preprocess of text
image_to_captions_mapping['1026685415_0431cbf574']
# Out:
# ['startseq black dog carries green toy in his mouth as he walks through the grass endseq',
#  'startseq black dog carrying something through the grass endseq',
#  'startseq black dog has blue toy in its mouth endseq',
#  'startseq dog in grass with blue item in his mouth endseq',
#  'startseq wet black dog is carrying green toy through the grass endseq']

# %%
# Creating a List of All Captions
all_captions = [caption for captions in image_to_captions_mapping.values() for caption in captions]

# %%
all_captions[:10]
# Out:
# ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#  'startseq girl going into wooden building endseq',
#  'startseq little girl climbing into wooden playhouse endseq',
#  'startseq little girl climbing the stairs to her playhouse endseq',
#  'startseq little girl in pink dress going into wooden cabin endseq',
#  'startseq black dog and spotted dog are fighting endseq',
#  'startseq black dog and tricolored dog playing with each other on the road endseq',
#  'startseq black dog and white dog with brown spots are staring at each other in the street endseq',
#  'startseq two dogs of different breeds looking at each other on the road endseq',
#  'startseq two dogs on pavement moving toward each other endseq']

# %%
# Tokenizing the Text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(all_captions)

# %%
# Save the tokenizer
with open('tokenizer.pkl', 'wb') as tokenizer_file:
    pickle.dump(tokenizer, tokenizer_file)

# Load the tokenizer
with open('tokenizer.pkl', 'rb') as tokenizer_file:
    tokenizer = pickle.load(tokenizer_file)

# %%
# Calculate maximum caption length
max_caption_length = max(len(tokenizer.texts_to_sequences([caption])[0]) for caption in all_captions)
vocab_size = len(tokenizer.word_index) + 1

# Print the results
print("Vocabulary Size:", vocab_size)
print("Maximum Caption Length:", max_caption_length)
# Out:
# Vocabulary Size: 8768
# Maximum Caption Length: 34

# %%
# Creating a List of Image IDs
image_ids = list(image_to_captions_mapping.keys())
# Splitting into Training and Test Sets
split = int(len(image_ids) * 0.90)
train = image_ids[:split]
test = image_ids[split:]

# %%
def data_generator(data_keys, image_to_captions_mapping, features, tokenizer, max_caption_length, vocab_size, batch_size):
    # Lists to store batch data
    X1_batch, X2_batch, y_batch = [], [], []
    # Counter for the current batch size
    batch_count = 0

    while True:
        # Loop through each image in the current batch
        for image_id in data_keys:
            # Get the captions associated with the current image
            captions = image_to_captions_mapping[image_id]

            # Loop through each caption for the current image
            for caption in captions:
                # Convert the caption to a sequence of token IDs
                caption_seq = tokenizer.texts_to_sequences([caption])[0]

                # Loop through the tokens in the caption sequence
                for i in range(1, len(caption_seq)):
                    # Split the sequence into input and output pairs
                    in_seq, out_seq = caption_seq[:i], caption_seq[i]

                    # Pad the input sequence to the specified maximum caption length
                    # Changed padding to 'post' to right pad the sequences
                    in_seq = pad_sequences([in_seq], maxlen=max_caption_length, padding='post')[0]

                    # Convert the output sequence to one-hot encoded format
                    out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]

                    # Append data to batch lists
                    X1_batch.append(features[image_id][0])  # Image features
                    X2_batch.append(in_seq)  # Input sequence
                    y_batch.append(out_seq)  # Output sequence

                    # Increase the batch counter
                    batch_count += 1

                    # If the batch is complete, yield the batch and reset lists and counter
                    if batch_count == batch_size:
                        X1_batch, X2_batch, y_batch = np.array(X1_batch), np.array(X2_batch), np.array(y_batch)
                        # yield ([X1_batch, X2_batch], y_batch) # Old yield statement

                        # New yield statement using tf.data.Dataset.from_generator
                        # The function expects a single argument therefore combine X1 and X2
                        # and specify the type and shape for from_generator

                        # Changed the keys to match the input layer names
                        yield ({'input_layer_11':X1_batch, 'input_layer_12': X2_batch}, y_batch)
                        X1_batch, X2_batch, y_batch = [], [], []
                        batch_count = 0

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# Define Adam optimizer with a custom learning rate
optimizer = Adam(learning_rate=5e-5)  # Example: setting a smaller learning rate

# Encoder model
inputs1 = Input(shape=(4096,), name='input_layer_11')  # Assign name 'input_layer_11'
fe1 = Dropout(0.5)(inputs1)
fe2 = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(fe1)  # Added L2 regularization
fe2_projected = RepeatVector(max_caption_length)(fe2)
fe2_projected = Bidirectional(LSTM(256, return_sequences=True))(fe2_projected)

# Sequence feature layers
inputs2 = Input(shape=(max_caption_length,), name='input_layer_12')  # Assign name 'input_layer_12'
se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
se2 = Dropout(0.5)(se1)
se3 = Bidirectional(LSTM(256, return_sequences=True))(se2)

# Apply attention mechanism using Dot product
attention = Dot(axes=[2, 2])([fe2_projected, se3])  # Calculate attention scores

# Softmax attention scores
attention_scores = Activation('softmax')(attention)

# Apply attention scores to sequence embeddings
attention_context = Lambda(lambda x: tf.einsum('ijk,ijl->ikl', x[0], x[1]))([attention_scores, se3])

# Sum the attended sequence embeddings along the time axis using a Lambda layer
context_vector = Lambda(lambda x: tf.reduce_sum(x, axis=1))(attention_context)  # Wrap tf.reduce_sum in a Lambda layer

# Decoder model
decoder_input = concatenate([context_vector, fe2], axis=-1)
decoder1 = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(decoder_input)  # Added L2 regularization
outputs = Dense(vocab_size, activation='softmax')(decoder1)

# Create the model
model = Model(inputs=[inputs1, inputs2], outputs=outputs)
# Compile the model with the custom optimizer
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Visualize the model
plot_model(model, show_shapes=True)

# %%
# Learning Rate Scheduler Callback
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=5e-5)

# To store metrics for plotting
train_loss = []
val_loss = []
train_acc = []
val_acc = []

# Set the number of epochs, batch size
epochs = 250
batch_size = 64

# Calculate the steps_per_epoch based on the number of batches in one epoch
steps_per_epoch = ceil(len(train) / batch_size)
validation_steps = ceil(len(test) / batch_size)  # Calculate the steps for validation data

# Loop through the epochs for training
for epoch in range(epochs):
    print(f"Epoch {epoch+1}/{epochs}")

    # Set up data generators
    train_generator = data_generator(train, image_to_captions_mapping, loaded_features, tokenizer, max_caption_length, vocab_size, batch_size)
    test_generator = data_generator(test, image_to_captions_mapping, loaded_features, tokenizer, max_caption_length, vocab_size, batch_size)

    history = model.fit(
        train_generator,
        epochs=1,
        steps_per_epoch=steps_per_epoch,
        validation_data=test_generator,
        validation_steps=validation_steps,
        verbose=1,
        callbacks=[lr_scheduler]  # Add learning rate scheduler callback
    )

    # Append metrics for visualization
    train_loss.append(history.history['loss'][0])
    val_loss.append(history.history['val_loss'][0])
    train_acc.append(history.history['accuracy'][0])
    val_acc.append(history.history['val_accuracy'][0])
# Out:
# Epoch 1/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 0.4525 - loss: 2.5827 - val_accuracy: 0.1478 - val_loss: 8.5674 - learning_rate: 5.0000e-05
# Epoch 2/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.4626 - loss: 2.5602 - val_accuracy: 0.1334 - val_loss: 8.6403 - learning_rate: 5.0000e-05
# Epoch 3/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.4654 - loss: 2.5550 - val_accuracy: 0.1454 - val_loss: 8.6404 - learning_rate: 5.0000e-05
# Epoch 4/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.4718 - loss: 2.5421 - val_accuracy: 0.1418 - val_loss: 8.6629 - learning_rate: 5.0000e-05
# Epoch 5/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.4680 - loss: 2.5295 - val_accuracy: 0.1418 - val_loss: 8.6745 - learning_rate: 5.0000e-05
# Epoch 6/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.4641 - loss: 2.5261 - val_accuracy: 0.1406 - val_loss: 8.6742 - learning_rate: 5.0000e-05
# Epoch 7/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.4729 - loss: 2.5034 - val_accuracy: 0.1418 - val_loss: 8.6757 - learning_rate: 5.0000e-05
# Epoch 8/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.4708 - loss: 2.5057 - val_accuracy: 0.1406 - val_loss: 8.6956 - learning_rate: 5.0000e-05
# Epoch 9/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.4661 - loss: 2.5011 - val_accuracy: 0.1430 - val_loss: 8.7047 - learning_rate: 5.0000e-05
# Epoch 10/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.4792 - loss: 2.4822 - val_accuracy: 0.1370 - val_loss: 8.7303 - learning_rate: 5.0000e-05
# Epoch 11/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.4770 - loss: 2.4770 - val_accuracy: 0.1418 - val_loss: 8.7387 - learning_rate: 5.0000e-05
# Epoch 12/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.4799 - loss: 2.4530 - val_accuracy: 0.1406 - val_loss: 8.7529 - learning_rate: 5.0000e-05
# Epoch 13/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.4853 - loss: 2.4511 - val_accuracy: 0.1406 - val_loss: 8.7771 - learning_rate: 5.0000e-05
# Epoch 14/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.4884 - loss: 2.4348 - val_accuracy: 0.1406 - val_loss: 8.7767 - learning_rate: 5.0000e-05
# Epoch 15/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.4830 - loss: 2.4400 - val_accuracy: 0.1370 - val_loss: 8.8027 - learning_rate: 5.0000e-05
# Epoch 16/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.4873 - loss: 2.4257 - val_accuracy: 0.1430 - val_loss: 8.8305 - learning_rate: 5.0000e-05
# Epoch 17/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.4939 - loss: 2.4043 - val_accuracy: 0.1466 - val_loss: 8.8310 - learning_rate: 5.0000e-05
# Epoch 18/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.4923 - loss: 2.4108 - val_accuracy: 0.1406 - val_loss: 8.8765 - learning_rate: 5.0000e-05
# Epoch 19/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.4963 - loss: 2.3816 - val_accuracy: 0.1430 - val_loss: 8.8224 - learning_rate: 5.0000e-05
# Epoch 20/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.4948 - loss: 2.3780 - val_accuracy: 0.1442 - val_loss: 8.8592 - learning_rate: 5.0000e-05
# Epoch 21/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.5035 - loss: 2.3664 - val_accuracy: 0.1502 - val_loss: 8.8288 - learning_rate: 5.0000e-05
# Epoch 22/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5054 - loss: 2.3529 - val_accuracy: 0.1430 - val_loss: 8.9173 - learning_rate: 5.0000e-05
# Epoch 23/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5015 - loss: 2.3539 - val_accuracy: 0.1514 - val_loss: 8.8926 - learning_rate: 5.0000e-05
# Epoch 24/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.5053 - loss: 2.3456 - val_accuracy: 0.1454 - val_loss: 8.9175 - learning_rate: 5.0000e-05
# Epoch 25/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.5040 - loss: 2.3300 - val_accuracy: 0.1466 - val_loss: 8.8807 - learning_rate: 5.0000e-05
# Epoch 26/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5004 - loss: 2.3259 - val_accuracy: 0.1490 - val_loss: 8.9369 - learning_rate: 5.0000e-05
# Epoch 27/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.5079 - loss: 2.3105 - val_accuracy: 0.1442 - val_loss: 8.9479 - learning_rate: 5.0000e-05
# Epoch 28/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5101 - loss: 2.3124 - val_accuracy: 0.1514 - val_loss: 8.9838 - learning_rate: 5.0000e-05
# Epoch 29/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5125 - loss: 2.2997 - val_accuracy: 0.1478 - val_loss: 8.9952 - learning_rate: 5.0000e-05
# Epoch 30/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.5186 - loss: 2.2795 - val_accuracy: 0.1418 - val_loss: 9.0328 - learning_rate: 5.0000e-05
# Epoch 31/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.5118 - loss: 2.2904 - val_accuracy: 0.1442 - val_loss: 8.9947 - learning_rate: 5.0000e-05
# Epoch 32/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5277 - loss: 2.2732 - val_accuracy: 0.1382 - val_loss: 8.9860 - learning_rate: 5.0000e-05
# Epoch 33/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5243 - loss: 2.2646 - val_accuracy: 0.1514 - val_loss: 9.0508 - learning_rate: 5.0000e-05
# Epoch 34/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.5303 - loss: 2.2519 - val_accuracy: 0.1358 - val_loss: 9.0290 - learning_rate: 5.0000e-05
# Epoch 35/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.5214 - loss: 2.2521 - val_accuracy: 0.1514 - val_loss: 9.0600 - learning_rate: 5.0000e-05
# Epoch 36/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5288 - loss: 2.2433 - val_accuracy: 0.1502 - val_loss: 9.0548 - learning_rate: 5.0000e-05
# Epoch 37/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5229 - loss: 2.2381 - val_accuracy: 0.1466 - val_loss: 9.0539 - learning_rate: 5.0000e-05
# Epoch 38/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.5313 - loss: 2.2259 - val_accuracy: 0.1478 - val_loss: 9.0824 - learning_rate: 5.0000e-05
# Epoch 39/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5289 - loss: 2.2288 - val_accuracy: 0.1430 - val_loss: 9.1036 - learning_rate: 5.0000e-05
# Epoch 40/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.5307 - loss: 2.2203 - val_accuracy: 0.1514 - val_loss: 9.0669 - learning_rate: 5.0000e-05
# Epoch 41/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.5379 - loss: 2.1975 - val_accuracy: 0.1502 - val_loss: 9.1094 - learning_rate: 5.0000e-05
# Epoch 42/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5385 - loss: 2.2051 - val_accuracy: 0.1430 - val_loss: 9.1686 - learning_rate: 5.0000e-05
# Epoch 43/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5437 - loss: 2.1774 - val_accuracy: 0.1478 - val_loss: 9.1128 - learning_rate: 5.0000e-05
# Epoch 44/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.5417 - loss: 2.1829 - val_accuracy: 0.1430 - val_loss: 9.1454 - learning_rate: 5.0000e-05
# Epoch 45/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.5524 - loss: 2.1685 - val_accuracy: 0.1454 - val_loss: 9.1828 - learning_rate: 5.0000e-05
# Epoch 46/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5423 - loss: 2.1703 - val_accuracy: 0.1454 - val_loss: 9.1376 - learning_rate: 5.0000e-05
# Epoch 47/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.5487 - loss: 2.1499 - val_accuracy: 0.1478 - val_loss: 9.1930 - learning_rate: 5.0000e-05
# Epoch 48/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.5443 - loss: 2.1604 - val_accuracy: 0.1466 - val_loss: 9.1933 - learning_rate: 5.0000e-05
# Epoch 49/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5517 - loss: 2.1423 - val_accuracy: 0.1478 - val_loss: 9.2321 - learning_rate: 5.0000e-05
# Epoch 50/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.5645 - loss: 2.1238 - val_accuracy: 0.1442 - val_loss: 9.2030 - learning_rate: 5.0000e-05
# Epoch 51/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.5566 - loss: 2.1121 - val_accuracy: 0.1466 - val_loss: 9.2278 - learning_rate: 5.0000e-05
# Epoch 52/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5482 - loss: 2.1269 - val_accuracy: 0.1478 - val_loss: 9.2273 - learning_rate: 5.0000e-05
# Epoch 53/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.5681 - loss: 2.1053 - val_accuracy: 0.1466 - val_loss: 9.2216 - learning_rate: 5.0000e-05
# Epoch 54/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.5607 - loss: 2.1165 - val_accuracy: 0.1370 - val_loss: 9.2686 - learning_rate: 5.0000e-05
# Epoch 55/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5543 - loss: 2.1040 - val_accuracy: 0.1466 - val_loss: 9.2122 - learning_rate: 5.0000e-05
# Epoch 56/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5579 - loss: 2.0951 - val_accuracy: 0.1514 - val_loss: 9.2604 - learning_rate: 5.0000e-05
# Epoch 57/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.5632 - loss: 2.0889 - val_accuracy: 0.1478 - val_loss: 9.2710 - learning_rate: 5.0000e-05
# Epoch 58/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5675 - loss: 2.0752 - val_accuracy: 0.1418 - val_loss: 9.2691 - learning_rate: 5.0000e-05
# Epoch 59/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5691 - loss: 2.0719 - val_accuracy: 0.1466 - val_loss: 9.3145 - learning_rate: 5.0000e-05
# Epoch 60/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.5672 - loss: 2.0861 - val_accuracy: 0.1466 - val_loss: 9.2843 - learning_rate: 5.0000e-05
# Epoch 61/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5732 - loss: 2.0546 - val_accuracy: 0.1478 - val_loss: 9.2952 - learning_rate: 5.0000e-05
# Epoch 62/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5742 - loss: 2.0634 - val_accuracy: 0.1466 - val_loss: 9.3191 - learning_rate: 5.0000e-05
# Epoch 63/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.5776 - loss: 2.0401 - val_accuracy: 0.1502 - val_loss: 9.3310 - learning_rate: 5.0000e-05
# Epoch 64/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.5752 - loss: 2.0337 - val_accuracy: 0.1562 - val_loss: 9.3249 - learning_rate: 5.0000e-05
# Epoch 65/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5846 - loss: 2.0307 - val_accuracy: 0.1418 - val_loss: 9.3590 - learning_rate: 5.0000e-05
# Epoch 66/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.5845 - loss: 2.0155 - val_accuracy: 0.1502 - val_loss: 9.3330 - learning_rate: 5.0000e-05
# Epoch 67/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.5680 - loss: 2.0275 - val_accuracy: 0.1550 - val_loss: 9.3669 - learning_rate: 5.0000e-05
# Epoch 68/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5780 - loss: 2.0168 - val_accuracy: 0.1442 - val_loss: 9.3503 - learning_rate: 5.0000e-05
# Epoch 69/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.5868 - loss: 2.0002 - val_accuracy: 0.1514 - val_loss: 9.3877 - learning_rate: 5.0000e-05
# Epoch 70/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.5818 - loss: 2.0099 - val_accuracy: 0.1538 - val_loss: 9.3640 - learning_rate: 5.0000e-05
# Epoch 71/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5872 - loss: 2.0036 - val_accuracy: 0.1538 - val_loss: 9.3952 - learning_rate: 5.0000e-05
# Epoch 72/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5902 - loss: 1.9982 - val_accuracy: 0.1599 - val_loss: 9.3812 - learning_rate: 5.0000e-05
# Epoch 73/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.5900 - loss: 1.9907 - val_accuracy: 0.1442 - val_loss: 9.4587 - learning_rate: 5.0000e-05
# Epoch 74/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5945 - loss: 1.9837 - val_accuracy: 0.1490 - val_loss: 9.4140 - learning_rate: 5.0000e-05
# Epoch 75/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.5983 - loss: 1.9695 - val_accuracy: 0.1478 - val_loss: 9.4434 - learning_rate: 5.0000e-05
# Epoch 76/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.5932 - loss: 1.9727 - val_accuracy: 0.1526 - val_loss: 9.4213 - learning_rate: 5.0000e-05
# Epoch 77/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.5968 - loss: 1.9665 - val_accuracy: 0.1514 - val_loss: 9.4720 - learning_rate: 5.0000e-05
# Epoch 78/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5993 - loss: 1.9608 - val_accuracy: 0.1418 - val_loss: 9.4654 - learning_rate: 5.0000e-05
# Epoch 79/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.5945 - loss: 1.9611 - val_accuracy: 0.1478 - val_loss: 9.4589 - learning_rate: 5.0000e-05
# Epoch 80/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6012 - loss: 1.9436 - val_accuracy: 0.1502 - val_loss: 9.4821 - learning_rate: 5.0000e-05
# Epoch 81/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6034 - loss: 1.9443 - val_accuracy: 0.1454 - val_loss: 9.4378 - learning_rate: 5.0000e-05
# Epoch 82/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.5980 - loss: 1.9298 - val_accuracy: 0.1466 - val_loss: 9.4993 - learning_rate: 5.0000e-05
# Epoch 83/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6062 - loss: 1.9324 - val_accuracy: 0.1382 - val_loss: 9.4383 - learning_rate: 5.0000e-05
# Epoch 84/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6088 - loss: 1.9240 - val_accuracy: 0.1430 - val_loss: 9.4700 - learning_rate: 5.0000e-05
# Epoch 85/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.6030 - loss: 1.9217 - val_accuracy: 0.1466 - val_loss: 9.4924 - learning_rate: 5.0000e-05
# Epoch 86/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.6078 - loss: 1.9082 - val_accuracy: 0.1538 - val_loss: 9.4601 - learning_rate: 5.0000e-05
# Epoch 87/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6094 - loss: 1.9154 - val_accuracy: 0.1514 - val_loss: 9.5129 - learning_rate: 5.0000e-05
# Epoch 88/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6079 - loss: 1.9060 - val_accuracy: 0.1514 - val_loss: 9.4646 - learning_rate: 5.0000e-05
# Epoch 89/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.6083 - loss: 1.8898 - val_accuracy: 0.1466 - val_loss: 9.4775 - learning_rate: 5.0000e-05
# Epoch 90/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6141 - loss: 1.8854 - val_accuracy: 0.1478 - val_loss: 9.5339 - learning_rate: 5.0000e-05
# Epoch 91/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6137 - loss: 1.8827 - val_accuracy: 0.1418 - val_loss: 9.5148 - learning_rate: 5.0000e-05
# Epoch 92/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.6161 - loss: 1.8871 - val_accuracy: 0.1442 - val_loss: 9.5809 - learning_rate: 5.0000e-05
# Epoch 93/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6216 - loss: 1.8756 - val_accuracy: 0.1466 - val_loss: 9.5586 - learning_rate: 5.0000e-05
# Epoch 94/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.6209 - loss: 1.8735 - val_accuracy: 0.1466 - val_loss: 9.5724 - learning_rate: 5.0000e-05
# Epoch 95/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.6281 - loss: 1.8662 - val_accuracy: 0.1418 - val_loss: 9.5757 - learning_rate: 5.0000e-05
# Epoch 96/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.6154 - loss: 1.8655 - val_accuracy: 0.1466 - val_loss: 9.5934 - learning_rate: 5.0000e-05
# Epoch 97/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6225 - loss: 1.8512 - val_accuracy: 0.1466 - val_loss: 9.5976 - learning_rate: 5.0000e-05
# Epoch 98/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.6261 - loss: 1.8490 - val_accuracy: 0.1394 - val_loss: 9.6065 - learning_rate: 5.0000e-05
# Epoch 99/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6240 - loss: 1.8463 - val_accuracy: 0.1478 - val_loss: 9.6101 - learning_rate: 5.0000e-05
# Epoch 100/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6188 - loss: 1.8506 - val_accuracy: 0.1430 - val_loss: 9.5716 - learning_rate: 5.0000e-05
# Epoch 101/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6250 - loss: 1.8468 - val_accuracy: 0.1490 - val_loss: 9.6330 - learning_rate: 5.0000e-05
# Epoch 102/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6295 - loss: 1.8297 - val_accuracy: 0.1490 - val_loss: 9.5925 - learning_rate: 5.0000e-05
# Epoch 103/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6260 - loss: 1.8303 - val_accuracy: 0.1478 - val_loss: 9.6415 - learning_rate: 5.0000e-05
# Epoch 104/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6319 - loss: 1.8176 - val_accuracy: 0.1478 - val_loss: 9.6261 - learning_rate: 5.0000e-05
# Epoch 105/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.6302 - loss: 1.8213 - val_accuracy: 0.1562 - val_loss: 9.6491 - learning_rate: 5.0000e-05
# Epoch 106/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6252 - loss: 1.8196 - val_accuracy: 0.1478 - val_loss: 9.6663 - learning_rate: 5.0000e-05
# Epoch 107/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6422 - loss: 1.8130 - val_accuracy: 0.1490 - val_loss: 9.6869 - learning_rate: 5.0000e-05
# Epoch 108/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.6366 - loss: 1.7996 - val_accuracy: 0.1466 - val_loss: 9.6229 - learning_rate: 5.0000e-05
# Epoch 109/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.6302 - loss: 1.8033 - val_accuracy: 0.1454 - val_loss: 9.7269 - learning_rate: 5.0000e-05
# Epoch 110/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6348 - loss: 1.7924 - val_accuracy: 0.1454 - val_loss: 9.6911 - learning_rate: 5.0000e-05
# Epoch 111/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.6325 - loss: 1.7911 - val_accuracy: 0.1514 - val_loss: 9.7006 - learning_rate: 5.0000e-05
# Epoch 112/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6320 - loss: 1.7961 - val_accuracy: 0.1502 - val_loss: 9.6968 - learning_rate: 5.0000e-05
# Epoch 113/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6354 - loss: 1.7791 - val_accuracy: 0.1490 - val_loss: 9.7091 - learning_rate: 5.0000e-05
# Epoch 114/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.6481 - loss: 1.7655 - val_accuracy: 0.1490 - val_loss: 9.7349 - learning_rate: 5.0000e-05
# Epoch 115/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6385 - loss: 1.7777 - val_accuracy: 0.1502 - val_loss: 9.7300 - learning_rate: 5.0000e-05
# Epoch 116/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6441 - loss: 1.7639 - val_accuracy: 0.1454 - val_loss: 9.7417 - learning_rate: 5.0000e-05
# Epoch 117/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.6453 - loss: 1.7507 - val_accuracy: 0.1490 - val_loss: 9.7440 - learning_rate: 5.0000e-05
# Epoch 118/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6455 - loss: 1.7468 - val_accuracy: 0.1514 - val_loss: 9.7725 - learning_rate: 5.0000e-05
# Epoch 119/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6526 - loss: 1.7544 - val_accuracy: 0.1478 - val_loss: 9.7536 - learning_rate: 5.0000e-05
# Epoch 120/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.6407 - loss: 1.7552 - val_accuracy: 0.1575 - val_loss: 9.7502 - learning_rate: 5.0000e-05
# Epoch 121/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6491 - loss: 1.7436 - val_accuracy: 0.1490 - val_loss: 9.7690 - learning_rate: 5.0000e-05
# Epoch 122/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6426 - loss: 1.7438 - val_accuracy: 0.1538 - val_loss: 9.7494 - learning_rate: 5.0000e-05
# Epoch 123/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.6610 - loss: 1.7238 - val_accuracy: 0.1526 - val_loss: 9.7902 - learning_rate: 5.0000e-05
# Epoch 124/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.6507 - loss: 1.7241 - val_accuracy: 0.1526 - val_loss: 9.7807 - learning_rate: 5.0000e-05
# Epoch 125/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6535 - loss: 1.7213 - val_accuracy: 0.1514 - val_loss: 9.8222 - learning_rate: 5.0000e-05
# Epoch 126/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6488 - loss: 1.7235 - val_accuracy: 0.1562 - val_loss: 9.7734 - learning_rate: 5.0000e-05
# Epoch 127/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.6527 - loss: 1.7207 - val_accuracy: 0.1526 - val_loss: 9.8075 - learning_rate: 5.0000e-05
# Epoch 128/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6554 - loss: 1.7082 - val_accuracy: 0.1562 - val_loss: 9.7909 - learning_rate: 5.0000e-05
# Epoch 129/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6538 - loss: 1.7086 - val_accuracy: 0.1575 - val_loss: 9.8047 - learning_rate: 5.0000e-05
# Epoch 130/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.6475 - loss: 1.7107 - val_accuracy: 0.1526 - val_loss: 9.8004 - learning_rate: 5.0000e-05
# Epoch 131/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6595 - loss: 1.6950 - val_accuracy: 0.1550 - val_loss: 9.8462 - learning_rate: 5.0000e-05
# Epoch 132/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6663 - loss: 1.6958 - val_accuracy: 0.1478 - val_loss: 9.8046 - learning_rate: 5.0000e-05
# Epoch 133/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.6617 - loss: 1.6937 - val_accuracy: 0.1502 - val_loss: 9.8497 - learning_rate: 5.0000e-05
# Epoch 134/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6628 - loss: 1.6961 - val_accuracy: 0.1502 - val_loss: 9.8856 - learning_rate: 5.0000e-05
# Epoch 135/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6689 - loss: 1.6884 - val_accuracy: 0.1562 - val_loss: 9.8507 - learning_rate: 5.0000e-05
# Epoch 136/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.6642 - loss: 1.6821 - val_accuracy: 0.1514 - val_loss: 9.8766 - learning_rate: 5.0000e-05
# Epoch 137/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6641 - loss: 1.6831 - val_accuracy: 0.1575 - val_loss: 9.8616 - learning_rate: 5.0000e-05
# Epoch 138/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6629 - loss: 1.6781 - val_accuracy: 0.1575 - val_loss: 9.8972 - learning_rate: 5.0000e-05
# Epoch 139/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.6781 - loss: 1.6564 - val_accuracy: 0.1514 - val_loss: 9.8849 - learning_rate: 5.0000e-05
# Epoch 140/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6629 - loss: 1.6615 - val_accuracy: 0.1562 - val_loss: 9.8634 - learning_rate: 5.0000e-05
# Epoch 141/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6674 - loss: 1.6698 - val_accuracy: 0.1550 - val_loss: 9.8882 - learning_rate: 5.0000e-05
# Epoch 142/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.6673 - loss: 1.6572 - val_accuracy: 0.1550 - val_loss: 9.9399 - learning_rate: 5.0000e-05
# Epoch 143/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6732 - loss: 1.6557 - val_accuracy: 0.1550 - val_loss: 9.9034 - learning_rate: 5.0000e-05
# Epoch 144/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6763 - loss: 1.6513 - val_accuracy: 0.1575 - val_loss: 9.9537 - learning_rate: 5.0000e-05
# Epoch 145/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.6763 - loss: 1.6494 - val_accuracy: 0.1502 - val_loss: 9.9762 - learning_rate: 5.0000e-05
# Epoch 146/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6731 - loss: 1.6369 - val_accuracy: 0.1562 - val_loss: 9.9690 - learning_rate: 5.0000e-05
# Epoch 147/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6734 - loss: 1.6395 - val_accuracy: 0.1575 - val_loss: 9.9329 - learning_rate: 5.0000e-05
# Epoch 148/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6804 - loss: 1.6332 - val_accuracy: 0.1526 - val_loss: 9.9813 - learning_rate: 5.0000e-05
# Epoch 149/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.6825 - loss: 1.6280 - val_accuracy: 0.1562 - val_loss: 9.9863 - learning_rate: 5.0000e-05
# Epoch 150/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6729 - loss: 1.6223 - val_accuracy: 0.1562 - val_loss: 9.9563 - learning_rate: 5.0000e-05
# Epoch 151/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6863 - loss: 1.6161 - val_accuracy: 0.1538 - val_loss: 10.0027 - learning_rate: 5.0000e-05
# Epoch 152/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.6834 - loss: 1.6273 - val_accuracy: 0.1562 - val_loss: 10.0112 - learning_rate: 5.0000e-05
# Epoch 153/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.6776 - loss: 1.6175 - val_accuracy: 0.1550 - val_loss: 10.0350 - learning_rate: 5.0000e-05
# Epoch 154/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6824 - loss: 1.6174 - val_accuracy: 0.1526 - val_loss: 9.9980 - learning_rate: 5.0000e-05
# Epoch 155/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6859 - loss: 1.6100 - val_accuracy: 0.1575 - val_loss: 10.0332 - learning_rate: 5.0000e-05
# Epoch 156/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.6847 - loss: 1.6018 - val_accuracy: 0.1526 - val_loss: 10.0059 - learning_rate: 5.0000e-05
# Epoch 157/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6858 - loss: 1.5963 - val_accuracy: 0.1538 - val_loss: 10.0412 - learning_rate: 5.0000e-05
# Epoch 158/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6881 - loss: 1.6026 - val_accuracy: 0.1550 - val_loss: 10.0550 - learning_rate: 5.0000e-05
# Epoch 159/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.6868 - loss: 1.5911 - val_accuracy: 0.1550 - val_loss: 10.0499 - learning_rate: 5.0000e-05
# Epoch 160/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6904 - loss: 1.5911 - val_accuracy: 0.1538 - val_loss: 10.0427 - learning_rate: 5.0000e-05
# Epoch 161/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6901 - loss: 1.5798 - val_accuracy: 0.1550 - val_loss: 10.0180 - learning_rate: 5.0000e-05
# Epoch 162/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.6929 - loss: 1.5814 - val_accuracy: 0.1575 - val_loss: 10.0908 - learning_rate: 5.0000e-05
# Epoch 163/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.6920 - loss: 1.5764 - val_accuracy: 0.1550 - val_loss: 10.0899 - learning_rate: 5.0000e-05
# Epoch 164/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6886 - loss: 1.5767 - val_accuracy: 0.1599 - val_loss: 10.0568 - learning_rate: 5.0000e-05
# Epoch 165/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6902 - loss: 1.5779 - val_accuracy: 0.1550 - val_loss: 10.0874 - learning_rate: 5.0000e-05
# Epoch 166/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.6932 - loss: 1.5698 - val_accuracy: 0.1575 - val_loss: 10.0837 - learning_rate: 5.0000e-05
# Epoch 167/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.6957 - loss: 1.5599 - val_accuracy: 0.1611 - val_loss: 10.0554 - learning_rate: 5.0000e-05
# Epoch 168/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6959 - loss: 1.5667 - val_accuracy: 0.1502 - val_loss: 10.1019 - learning_rate: 5.0000e-05
# Epoch 169/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6940 - loss: 1.5679 - val_accuracy: 0.1587 - val_loss: 10.1128 - learning_rate: 5.0000e-05
# Epoch 170/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.7007 - loss: 1.5553 - val_accuracy: 0.1550 - val_loss: 10.0866 - learning_rate: 5.0000e-05
# Epoch 171/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6976 - loss: 1.5590 - val_accuracy: 0.1599 - val_loss: 10.1298 - learning_rate: 5.0000e-05
# Epoch 172/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.6922 - loss: 1.5516 - val_accuracy: 0.1526 - val_loss: 10.1069 - learning_rate: 5.0000e-05
# Epoch 173/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7017 - loss: 1.5523 - val_accuracy: 0.1526 - val_loss: 10.1296 - learning_rate: 5.0000e-05
# Epoch 174/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7018 - loss: 1.5454 - val_accuracy: 0.1502 - val_loss: 10.1215 - learning_rate: 5.0000e-05
# Epoch 175/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.6916 - loss: 1.5450 - val_accuracy: 0.1514 - val_loss: 10.1367 - learning_rate: 5.0000e-05
# Epoch 176/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7000 - loss: 1.5294 - val_accuracy: 0.1538 - val_loss: 10.1436 - learning_rate: 5.0000e-05
# Epoch 177/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7013 - loss: 1.5297 - val_accuracy: 0.1490 - val_loss: 10.1670 - learning_rate: 5.0000e-05
# Epoch 178/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.7057 - loss: 1.5283 - val_accuracy: 0.1466 - val_loss: 10.1914 - learning_rate: 5.0000e-05
# Epoch 179/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7013 - loss: 1.5236 - val_accuracy: 0.1538 - val_loss: 10.1814 - learning_rate: 5.0000e-05
# Epoch 180/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7072 - loss: 1.5228 - val_accuracy: 0.1466 - val_loss: 10.1866 - learning_rate: 5.0000e-05
# Epoch 181/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.6959 - loss: 1.5235 - val_accuracy: 0.1538 - val_loss: 10.1840 - learning_rate: 5.0000e-05
# Epoch 182/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7006 - loss: 1.5179 - val_accuracy: 0.1550 - val_loss: 10.1851 - learning_rate: 5.0000e-05
# Epoch 183/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7101 - loss: 1.5088 - val_accuracy: 0.1550 - val_loss: 10.2014 - learning_rate: 5.0000e-05
# Epoch 184/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.7097 - loss: 1.5144 - val_accuracy: 0.1514 - val_loss: 10.2325 - learning_rate: 5.0000e-05
# Epoch 185/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.7106 - loss: 1.5019 - val_accuracy: 0.1514 - val_loss: 10.2088 - learning_rate: 5.0000e-05
# Epoch 186/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7156 - loss: 1.4944 - val_accuracy: 0.1575 - val_loss: 10.2123 - learning_rate: 5.0000e-05
# Epoch 187/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.7086 - loss: 1.5026 - val_accuracy: 0.1526 - val_loss: 10.1903 - learning_rate: 5.0000e-05
# Epoch 188/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.7194 - loss: 1.4955 - val_accuracy: 0.1562 - val_loss: 10.1767 - learning_rate: 5.0000e-05
# Epoch 189/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7103 - loss: 1.4988 - val_accuracy: 0.1562 - val_loss: 10.2248 - learning_rate: 5.0000e-05
# Epoch 190/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7089 - loss: 1.4940 - val_accuracy: 0.1490 - val_loss: 10.2218 - learning_rate: 5.0000e-05
# Epoch 191/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.7120 - loss: 1.4892 - val_accuracy: 0.1526 - val_loss: 10.2126 - learning_rate: 5.0000e-05
# Epoch 192/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7174 - loss: 1.4866 - val_accuracy: 0.1466 - val_loss: 10.2391 - learning_rate: 5.0000e-05
# Epoch 193/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7074 - loss: 1.4910 - val_accuracy: 0.1587 - val_loss: 10.2103 - learning_rate: 5.0000e-05
# Epoch 194/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.7127 - loss: 1.4787 - val_accuracy: 0.1442 - val_loss: 10.3007 - learning_rate: 5.0000e-05
# Epoch 195/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7139 - loss: 1.4715 - val_accuracy: 0.1418 - val_loss: 10.2296 - learning_rate: 5.0000e-05
# Epoch 196/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7220 - loss: 1.4737 - val_accuracy: 0.1490 - val_loss: 10.2620 - learning_rate: 5.0000e-05
# Epoch 197/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.7225 - loss: 1.4650 - val_accuracy: 0.1490 - val_loss: 10.2442 - learning_rate: 5.0000e-05
# Epoch 198/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.7132 - loss: 1.4748 - val_accuracy: 0.1490 - val_loss: 10.3096 - learning_rate: 5.0000e-05
# Epoch 199/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7241 - loss: 1.4611 - val_accuracy: 0.1575 - val_loss: 10.2867 - learning_rate: 5.0000e-05
# Epoch 200/250
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.7194 - loss: 1.4655 - val_accuracy: 0.1466 - val_loss: 10.2828 - learning_rate: 5.0000e-05
# Epoch 201/250
# 113/114 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7206 - loss: 1.4557

# %%
import matplotlib.pyplot as plt

# Plot the training and validation loss
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(range(1, epochs + 1), train_loss, label='Train Loss')
plt.plot(range(1, epochs + 1), val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Plot the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(range(1, epochs + 1), train_acc, label='Train Accuracy')
plt.plot(range(1, epochs + 1), val_acc, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Save the model
model.save(OUTPUT_DIR+'/image_captioning_model_v1.h5')

# %%
def get_word_from_index(index, tokenizer):
    return next((word for word, idx in tokenizer.word_index.items() if idx == index), None)

# %%
def predict_caption(model, image_features, tokenizer, max_caption_length):
    # Initialize the caption sequence
    caption = 'startseq'

    # Generate the caption
    for _ in range(max_caption_length):
        # Convert the current caption to a sequence of token indices
        sequence = tokenizer.texts_to_sequences([caption])[0]
        # Pad the sequence to match the maximum caption length, ensuring right padding
        sequence = pad_sequences([sequence], maxlen=max_caption_length, padding='post')  # Changed padding to 'post'
        # Predict the next word's probability distribution
        yhat = model.predict([image_features, sequence], verbose=0)
        # Get the index with the highest probability
        predicted_index = np.argmax(yhat)
        # Convert the index to a word
        predicted_word = get_word_from_index(predicted_index, tokenizer)

        # Append the predicted word to the caption
        caption += " " + predicted_word

        # Stop if the word is None or if the end sequence tag is encountered
        if predicted_word is None or predicted_word == 'endseq':
            break

    return caption

# %%
# !pip install rouge-score
# !pip install nltk
import nltk
nltk.download('wordnet')
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (4.67.1)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=83e2b2d0c39efae756b3bc8436fe702ce46411768e34e1299d65f521b4a30743
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.67.1)
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# Required Imports
from tqdm import tqdm
from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.meteor_score import meteor_score
from rouge_score import rouge_scorer
from collections import defaultdict
import pandas as pd

# Initialize lists to store actual and predicted captions
actual_captions_list = []
predicted_captions_list = []

# Metrics storage
meteor_scores = []
rouge_scores = defaultdict(list)

# Loop through the test data
for key in tqdm(test):
    # Get actual captions for the current image
    actual_captions = image_to_captions_mapping[key]
    # Predict the caption for the image using the model
    predicted_caption = predict_caption(model, loaded_features[key], tokenizer, max_caption_length)

    # Split actual captions into words
    actual_captions_words = [caption.split() for caption in actual_captions]  # Tokenize actual captions
    # Split predicted caption into words
    predicted_caption_words = predicted_caption.split()

    # Append to the lists
    actual_captions_list.append(actual_captions_words)
    predicted_captions_list.append(predicted_caption_words)

    # Calculate METEOR
    # Pass tokenized actual captions to meteor_score
    meteor_scores.append(
        max([meteor_score([caption.split()], predicted_caption.split()) for caption in actual_captions])
    )
    # Calculate ROUGE
    scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL"], use_stemmer=True)
    for caption in actual_captions:
        scores = scorer.score(caption, predicted_caption)
        for metric, score in scores.items():
            rouge_scores[metric].append(score.fmeasure)

# Calculate BLEU scores
bleu1 = corpus_bleu(actual_captions_list, predicted_captions_list, weights=(1.0, 0, 0, 0))
bleu2 = corpus_bleu(actual_captions_list, predicted_captions_list, weights=(0.5, 0.5, 0, 0))
bleu3 = corpus_bleu(actual_captions_list, predicted_captions_list, weights=(0.33, 0.33, 0.33, 0))
bleu4 = corpus_bleu(actual_captions_list, predicted_captions_list, weights=(0.25, 0.25, 0.25, 0.25))

# Calculate average ROUGE scores
avg_rouge1 = sum(rouge_scores["rouge1"]) / len(rouge_scores["rouge1"])
avg_rouge2 = sum(rouge_scores["rouge2"]) / len(rouge_scores["rouge2"])
avg_rougeL = sum(rouge_scores["rougeL"]) / len(rouge_scores["rougeL"])

# Create table
metrics_table = pd.DataFrame({
    "Metric": ["BLEU-1", "BLEU-2", "BLEU-3", "BLEU-4", "METEOR", "ROUGE-1", "ROUGE-2", "ROUGE-L"],
    "Score": [
        bleu1,
        bleu2,
        bleu3,
        bleu4,
        sum(meteor_scores) / len(meteor_scores),
        avg_rouge1,
        avg_rouge2,
        avg_rougeL,
    ]
})

# Print table
print("/n")
print(metrics_table.to_markdown(index=False))

# %%
# Function for generating caption
def generate_caption(image_name):
    # load the image
    image_id = image_name.split('.')[0]
    img_path = os.path.join(INPUT_DIR, "Images", image_name)
    image = Image.open(img_path)
    captions = image_to_captions_mapping[image_id]
    print('---------------------Actual---------------------')
    for caption in captions:
        print(caption)
    # predict the caption
    y_pred = predict_caption(model, loaded_features[image_id], tokenizer, max_caption_length)
    print('--------------------Predicted--------------------')
    print(y_pred)
    plt.imshow(image)

# %%
generate_caption("1001773457_577c3a7d70.jpg")
# Out:
# ---------------------Actual---------------------
# startseq black dog and spotted dog are fighting endseq
# startseq black dog and tricolored dog playing with each other on the road endseq
# startseq black dog and white dog with brown spots are staring at each other in the street endseq
# startseq two dogs of different breeds looking at each other on the road endseq
# startseq two dogs on pavement moving toward each other endseq
# --------------------Predicted--------------------
# startseq two dogs on pavement moving toward each other endseq

# %%
# We are going to use pretraind vgg model
# Load the vgg16 model
model_1 = VGG16()

# Restructuring the model to remove the last classification layer, this will give us access to the output features of the model
model_1 = Model(inputs=model_1.inputs, outputs=model_1.layers[-2].output)


def generate_caption_for_new_image(image_path):
    # Load and preprocess the new image
    image = load_img(image_path, target_size=(224, 224))
    image = img_to_array(image)
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    image = preprocess_input(image)

    # Extract features using the pre-trained ResNet50 model
    image_features = model_1.predict(image, verbose=0)  # Replace 'model' with 'feature_extraction_model'

    # Generate caption
    caption = 'startseq'
    for _ in range(max_caption_length):
        # Convert the current caption to a sequence
        sequence = tokenizer.texts_to_sequences([caption])[0]
        sequence = pad_sequences([sequence], maxlen=max_caption_length, padding='post')

        # Predict the next word
        yhat = model.predict([image_features, sequence], verbose=0)  # Use the caption generation model
        predicted_index = np.argmax(yhat)
        predicted_word = get_word_from_index(predicted_index, tokenizer)

        if predicted_word is None or predicted_word == 'endseq':
            break
        caption += ' ' + predicted_word

    # Remove startseq and endseq for readability
    caption = caption.replace('startseq', '').replace('endseq', '').strip()

    # Display the image and its caption
    img = Image.open(image_path)
    plt.imshow(img)
    plt.axis('off')
    plt.title("Predicted Caption:\n" + caption)
    plt.show()

# Example usage:
new_image_path = 'download.jpeg'  # Replace with your image path
generate_caption_for_new_image(new_image_path)
